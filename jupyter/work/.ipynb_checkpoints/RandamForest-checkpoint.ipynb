# %%
import csv
import requests
from bs4 import BeautifulSoup

def get_market_csv(each_url, name):
    url = 'https://kabuoji3.com/stock/' + each_url + '/'
    headers = {"User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:47.0) Gecko/20100101 Firefox/47.0"}
    resp = requests.get(url, headers=headers)
    soup = BeautifulSoup(resp.text.encode(resp.encoding), "html5lib")
    table = soup.findAll("table",{"class":"stock_table"})

    all_rows = []
    for item in table:
        rows = item.findAll("tr")
        del rows[0]
        all_rows.append(rows)

    csvFile = open(name + '.csv', 'wt', newline = '', encoding = 'utf-8')
    writer = csv.writer(csvFile)

    try:
        writer.writerow(['Date','Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close'])
        for rows in all_rows:
            for row in rows:
                csvRow = []
                for cell in row.findAll(['td', 'th']):
                    csvRow.append(cell.get_text())
                writer.writerow(csvRow)
    finally:
        csvFile.close()

# %%
markets = {
    'maruhanichiro': 1333,
    'samsun200': 1313,
    'shanghai50': 1309,
}

# %%
for name, code in markets.items():
    get_market_csv(str(code), name)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.finance import candlestick2_ohlc, volume_overlay
# %matplotlib inline

# %%
dfs = {}
for name in markets.keys():
    dfs[name] = pd.read_csv(name + '.csv', parse_dates=True)

# %%
def show_market(df):
    fig = plt.figure(figsize=(50, 9))
    ax = plt.subplot(1, 1, 1)

    candlestick2_ohlc(ax, df["Open"], df["High"], df["Low"], df["Adj Close"], width=0.9, colorup="b", colordown="r")

# %%
for df in dfs.values():
    show_market(df)

# %%
df_main = dfs["maruhanichiro"].copy()
df_main
# Out:
#            Date  Open  High   Low  Close   Volume  Adj Close
# 0    2018-03-14  3280  3325  3275   3315   146600       3315
# 1    2018-03-13  3245  3285  3235   3270   112400       3270
# 2    2018-03-12  3275  3280  3230   3250   141800       3250
# 3    2018-03-09  3290  3335  3255   3260   317400       3260
# 4    2018-03-08  3275  3295  3255   3275   201200       3275
# 5    2018-03-07  3290  3330  3275   3300   216400       3300
# 6    2018-03-06  3230  3305  3230   3285   294300       3285
# 7    2018-03-05  3165  3210  3165   3200   174300       3200
# 8    2018-03-02  3165  3200  3160   3175   215300       3175
# 9    2018-03-01  3175  3215  3160   3180   217500       3180
# 10   2018-02-28  3190  3210  3155   3160   276300       3160
# 11   2018-02-27  3245  3245  3190   3195   151300       3195
# 12   2018-02-26  3255  3260  3220   3220   131300       3220
# 13   2018-02-23  3225  3240  3205   3215   213500       3215
# 14   2018-02-22  3255  3255  3220   3225   196600       3225
# 15   2018-02-21  3300  3330  3280   3310   172600       3310
# 16   2018-02-20  3320  3355  3310   3345   137600       3345
# 17   2018-02-19  3275  3340  3270   3330   137100       3330
# 18   2018-02-16  3200  3275  3185   3250   172000       3250
