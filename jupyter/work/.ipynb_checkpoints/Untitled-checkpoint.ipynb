# %%
import pandas as pd
from datetime import datetime, timedelta
baseApiUrl = 'https://bitcoincharts.com/charts/chart.json?'
market = 'coincheckJPY'

# %%
dates = {
    "from": {
        "year": 2017,
        "month": 7,
        "day": 14
    },
    "to": {
        "year": 2017,
        "month": 8,
        "day": 9
    },
}
def getDates(startDate, stopDate):
    dateArray = []
    currentDate = startDate
    while currentDate <= stopDate:
        dateArray.append(currentDate)
        currentDate = currentDate + timedelta(days=1)
    return dateArray
def formatApiUrl(market, date):
    apiUrl = baseApiUrl + 'm=' + market + '&SubmitButton=Draw&r=60&i=1-min&c=1&s=' + date + '&e=' + date + '&Prev=&Next=&t=S&b=&a1=&m1=10&a2=&m2=25&x=0&i1=&i2=&i3=&i4=&v=1&cv=0&ps=0&l=0&p=0&'
    return apiUrl

# %%
start = datetime(dates["from"]["year"], dates["from"]["month"], dates["from"]["day"])
end = datetime(dates["to"]["year"], dates["to"]["month"], dates["to"]["day"])
dateStack = getDates(start, end)
chartDf = pd.DataFrame([], columns=['timestamp', 'open', 'high', 'low', 'close', 'volume_btc', 'volume_currency', 'weighted_price'])
print(chartDf)
for date in dateStack:
    prettyDate = date.strftime('%Y-%m-%d')
    dataPath = formatApiUrl(market, prettyDate)
    print(dataPath)
    df = pd.read_json(
            dataPath
    )
    df.columns = ['timestamp', 'open', 'high', 'low', 'close', 'volume_btc', 'volume_currency', 'weighted_price']
    print(df)
    chartDf = pd.concat(chartDf, df)
chartDf
# Out:
# Empty DataFrame
# Columns: [timestamp, open, high, low, close, volume_btc, volume_currency, weighted price]
# Index: []
# https://bitcoincharts.com/charts/chart.json?m=coincheckJPY&SubmitButton=Draw&r=60&i=1-min&c=1&s=2017-07-14&e=2017-07-14&Prev=&Next=&t=S&b=&a1=&m1=10&a2=&m2=25&x=0&i1=&i2=&i3=&i4=&v=1&cv=0&ps=0&l=0&p=0&
#        timestamp    open    high     low   close  volume_btc  volume_currency  \
# 0     1499904000  272400  272513  272400  272432    4.733856     1.289540e+06
# 1     1499904060  272440  272765  272413  272428   11.233155     3.062895e+06
# 2     1499904120  272510  272606  272400  272516   18.601512     5.069188e+06
# 3     1499904180  272501  272605  272499  272503    1.407838     3.837267e+05
# 4     1499904240  272591  272606  272524  272601   10.392563     2.832646e+06
# 5     1499904300  272600  272606  272600  272605   12.947447     3.529530e+06
# 6     1499904360  272605  273079  272600  272847    4.094578     1.116354e+06
# ...

# %%
df = pd.read_json('https://bitcoincharts.com/charts/chart.json?m=coincheckJPY&r=60&i=1-min&c=1&s=2016-09-14&e=2016-09-14&Prev=&Next=&t=S&b=&a1=&m1=10&a2=&m2=25&x=0&i1=&i2=&i3=&i4=&v=1&cv=0&ps=0&l=0&p=0&')
df
# Out:
#                0              1              2              3              4  \
# 0     1473725040   6.228400e+04   6.229800e+04   6.228400e+04   6.229800e+04
# 1     1473725100  1.700000e+308  1.700000e+308  1.700000e+308  1.700000e+308
# 2     1473725160  1.700000e+308  1.700000e+308  1.700000e+308  1.700000e+308
# 3     1473725220   6.226600e+04   6.226600e+04   6.226600e+04   6.226600e+04
# 4     1473725280   6.228800e+04   6.229300e+04   6.228800e+04   6.229300e+04
# 5     1473725340  1.700000e+308  1.700000e+308  1.700000e+308  1.700000e+308
# 6     1473725400   6.228800e+04   6.229400e+04   6.228800e+04   6.229400e+04
# 7     1473725460   6.229900e+04   6.229900e+04   6.229900e+04   6.229900e+04
# 8     1473725520  1.700000e+308  1.700000e+308  1.700000e+308  1.700000e+308
# 9     1473725580  1.700000e+308  1.700000e+308  1.700000e+308  1.700000e+308
# 10    1473725640  1.700000e+308  1.700000e+308  1.700000e+308  1.700000e+308
# ...
