# %%
import pymysql
from pandas.io import sql
import pandas as pd
import seaborn as sns
sns.set(font='Ricty Diminished',font_scale=2)
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option("display.max_colwidth", 200)
pd.set_option("display.max_rows", 101)
connection = pymysql.connect(host='db', db='ritz', user='root', password='password',charset="utf8",cursorclass=pymysql.cursors.DictCursor)

# %%
import matplotlib.font_manager as fm
fonts = fm.findSystemFonts()
l = []
for f in fonts:
    font = fm.FontProperties(fname=f)
    l.append((f, font.get_name(), font.get_family()))
df = pd.DataFrame(l, columns=['path', 'name', 'family'])
df[df['path'].apply(lambda s: 'IPA' in s)]
fm.fontManager.ttflist
# Out:
# [<Font 'DejaVu Sans' (DejaVuSans-Oblique.ttf) oblique normal 400 normal>,
#  <Font 'STIXSizeFourSym' (STIXSizFourSymReg.ttf) normal normal 400 normal>,
#  <Font 'STIXSizeOneSym' (STIXSizOneSymBol.ttf) normal normal 700 normal>,
#  <Font 'STIXSizeFourSym' (STIXSizFourSymBol.ttf) normal normal 700 normal>,
#  <Font 'DejaVu Sans Display' (DejaVuSansDisplay.ttf) normal normal 400 normal>,
#  <Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal 700 normal>,
#  <Font 'DejaVu Sans' (DejaVuSans-BoldOblique.ttf) oblique normal 700 normal>,
#  <Font 'STIXGeneral' (STIXGeneralBolIta.ttf) italic normal 700 normal>,
#  <Font 'cmex10' (cmex10.ttf) normal normal 400 normal>,
#  <Font 'cmtt10' (cmtt10.ttf) normal normal 400 normal>,
#  <Font 'STIXNonUnicode' (STIXNonUniBol.ttf) normal normal 700 normal>,
#  <Font 'STIXSizeTwoSym' (STIXSizTwoSymBol.ttf) normal normal 700 normal>,
#  <Font 'STIXNonUnicode' (STIXNonUniBolIta.ttf) italic normal 700 normal>,
#  <Font 'cmss10' (cmss10.ttf) normal normal 400 normal>,
#  <Font 'DejaVu Serif' (DejaVuSerif-BoldItalic.ttf) italic normal 700 normal>,
#  <Font 'DejaVu Serif Display' (DejaVuSerifDisplay.ttf) normal normal 400 normal>,
#  <Font 'STIXSizeThreeSym' (STIXSizThreeSymReg.ttf) normal normal 400 normal>,
#  <Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal 700 normal>,
#  <Font 'STIXGeneral' (STIXGeneralBol.ttf) normal normal 700 normal>,
#  <Font 'DejaVu Sans Mono' (DejaVuSansMono-BoldOblique.ttf) oblique normal 700 normal>,
#  <Font 'cmr10' (cmr10.ttf) normal normal 400 normal>,
#  <Font 'STIXSizeOneSym' (STIXSizOneSymReg.ttf) normal normal 400 normal>,
#  <Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>,
#  <Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal 700 normal>,
#  <Font 'cmb10' (cmb10.ttf) normal normal 400 normal>,
#  <Font 'STIXGeneral' (STIXGeneral.ttf) normal normal 400 normal>,
#  <Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>,
#  <Font 'cmsy10' (cmsy10.ttf) normal normal 400 normal>,
#  <Font 'DejaVu Sans Mono' (DejaVuSansMono-Oblique.ttf) oblique normal 400 normal>,
#  <Font 'STIXNonUnicode' (STIXNonUniIta.ttf) italic normal 400 normal>,
#  <Font 'STIXSizeThreeSym' (STIXSizThreeSymBol.ttf) normal normal 700 normal>,
#  <Font 'STIXSizeTwoSym' (STIXSizTwoSymReg.ttf) normal normal 400 normal>,
#  <Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>,
#  <Font 'STIXGeneral' (STIXGeneralItalic.ttf) italic normal 400 normal>,
#  <Font 'cmmi10' (cmmi10.ttf) normal normal 400 normal>,
#  <Font 'STIXSizeFiveSym' (STIXSizFiveSymReg.ttf) normal normal 400 normal>,
#  <Font 'STIXNonUnicode' (STIXNonUni.ttf) normal normal 400 normal>,
#  <Font 'DejaVu Serif' (DejaVuSerif-Italic.ttf) italic normal 400 normal>,
#  <Font 'Lato' (Lato-Bold.ttf) normal normal 700 normal>,
#  <Font 'Roboto' (Roboto-LightItalic.ttf) italic normal 200 normal>,
#  <Font 'Lobster Two' (lobster.otf) italic normal 700 normal>,
#  <Font 'Gentium Basic' (GenBasB.ttf) normal normal 700 normal>,
#  <Font 'EB Garamond' (EBGaramond08-Regular.ttf) normal normal 400 normal>,
#  <Font 'Accanthis ADF Std No2' (AccanthisADFStdNo2-Italic.otf) italic normal 400 normal>,
#  <Font 'STIXIntegralsUp' (STIXIntegralsUp-Regular.otf) normal normal 400 normal>,
#  <Font 'Ricty Diminished Discord for Powerline' (Ricty Diminished Discord Regular for Powerline.ttf) normal normal 400 normal>,
#  <Font 'FreeSans' (FreeSansOblique.otf) oblique normal 400 normal>,
#  <Font 'Ricty Diminished for Powerline' (Ricty Diminished Bold Oblique for Powerline.ttf) oblique normal 700 normal>,
#  <Font 'Ricty Diminished for Powerline' (RictyDiminished-Regular-Powerline.ttf) normal normal 400 normal>,
#  <Font 'Accanthis ADF Std' (AccanthisADFStd-Italic.otf) italic normal 400 normal>,
#  <Font 'Gentium Basic' (GenBasR.ttf) normal normal 400 normal>,
#  <Font 'Cabin' (Cabin-Regular.otf) normal normal 400 normal>,
#  <Font 'STIXSizeOneSym' (STIXSizeOneSym-Bold.otf) normal normal 700 normal>,
#  <Font 'Roboto Condensed' (RobotoCondensed-LightItalic.ttf) italic normal 200 condensed>,
#  <Font 'Ricty Diminished for Powerline' (Ricty Diminished Bold for Powerline.ttf) normal normal 700 normal>,
#  <Font 'Gillius ADF No2 Cd' (GilliusADFNo2Cd-Bold.otf) normal normal 700 normal>,
#  <Font 'FreeMono' (FreeMonoBoldOblique.ttf) oblique normal 700 normal>,
#  <Font 'Comfortaa' (Comfortaa-Bold.ttf) normal normal 700 normal>,
#  <Font 'STIXIntegralsUpSm' (STIXIntegralsUpSm-Bold.otf) normal normal 700 normal>,
#  <Font 'Linux Libertine Display O' (LinLibertine_DR.otf) normal normal 400 normal>,
#  <Font 'DejaVu Sans' (DejaVuSansCondensed-BoldOblique.ttf) oblique normal 700 condensed>,
#  <Font 'FontAwesome' (FontAwesome.otf) normal normal 400 normal>,
#  <Font 'DejaVu Serif' (DejaVuSerifCondensed-BoldItalic.ttf) italic normal 700 condensed>,
#  <Font 'Gentium Basic' (GenBasBI.ttf) italic normal 700 normal>,
#  <Font 'Lobster Two' (LobsterTwo-Italic.otf) italic normal 400 normal>,
#  <Font 'FreeMono' (FreeMonoBold.otf) normal normal 700 normal>,
#  <Font 'FreeSerif' (FreeSerifBoldItalic.ttf) italic normal 700 normal>,
#  <Font 'Caladea' (Caladea-Italic.ttf) italic normal 400 normal>,
#  <Font 'FontAwesome' (fontawesome-webfont.ttf) normal normal 400 normal>,
#  <Font 'FreeMono' (FreeMonoOblique.otf) oblique normal 400 normal>,
#  <Font 'Accanthis ADF Std No2' (AccanthisADFStdNo2-Regular.otf) normal normal 400 normal>,
#  <Font 'Lobster Two' (LobsterTwo-Regular.otf) normal normal 400 normal>,
#  <Font 'Roboto Condensed' (RobotoCondensed-BoldItalic.ttf) italic normal 700 condensed>,
#  <Font 'Liberation Sans Narrow' (LiberationSansNarrow-Italic.ttf) italic normal 400 condensed>,
#  <Font 'STIXIntegralsD' (STIXIntegralsD-Bold.otf) normal normal 700 normal>,
#  <Font 'GFS Didot' (GFSDidot.otf) normal normal 400 normal>,
#  <Font 'Universalis ADF Std' (UniversalisADFStd-Bold.otf) normal normal 700 normal>,
#  <Font 'Linux Libertine O' (LinLibertine_RI.otf) italic normal 400 normal>,
#  <Font 'Liberation Mono' (LiberationMono-Bold.ttf) normal normal 700 normal>,
#  <Font 'Universalis ADF Std' (UniversalisADFStd-Oblique.otf) oblique normal 400 normal>,
#  <Font 'Junicode' (Junicode-BoldItalic.ttf) italic normal 700 normal>,
#  <Font 'DejaVu Serif' (DejaVuSerifCondensed-Bold.ttf) normal normal 700 condensed>,
#  <Font 'Ricty Diminished Discord for Powerline' (RictyDiminishedDiscord-Oblique-Powerline.ttf) oblique normal 400 normal>,
#  <Font 'IPAPGothic' (ipagp.ttf) normal normal 400 normal>,
#  <Font 'STIXSizeTwoSym' (STIXSizeTwoSym-Regular.otf) normal normal 400 normal>,
#  <Font 'Lato' (Lato-Regular.ttf) normal normal 400 normal>,
#  <Font 'GFS Neohellenic' (GFSNeohellenicIt.otf) italic normal 400 normal>,
#  <Font 'Liberation Serif' (LiberationSerif-BoldItalic.ttf) italic normal 700 normal>,
#  <Font 'FreeMono' (FreeMono.otf) normal normal 400 normal>,
#  <Font 'Gentium Book Basic' (GenBkBasBI.ttf) italic normal 400 normal>,
#  <Font 'Liberation Sans' (LiberationSans-Italic.ttf) italic normal 400 normal>,
#  <Font 'FreeMono' (FreeMonoBold.ttf) normal normal 700 normal>,
#  <Font 'EB Garamond' (EBGaramond08-Italic.ttf) italic normal 400 normal>,
#  <Font 'Ricty Diminished for Powerline' (RictyDiminished-Bold-Powerline.ttf) normal normal 700 normal>,
#  <Font 'Gillius ADF' (GilliusADF-Regular.otf) normal normal 400 normal>,
#  <Font 'Lato' (Lato-Italic.ttf) italic normal 400 normal>,
#  <Font 'Carlito' (Carlito-BoldItalic.ttf) italic normal 700 normal>,
#  <Font 'FreeMono' (FreeMonoOblique.ttf) oblique normal 400 normal>,
#  <Font 'FreeSerif' (FreeSerifItalic.otf) italic normal 400 normal>,
#  <Font 'Linux Libertine Initials O' (LinLibertine_I.otf) normal normal 400 normal>,
#  <Font 'Lato' (Lato-BlackItalic.ttf) italic normal 900 normal>,
#  <Font 'DejaVu Sans' (DejaVuSansCondensed.ttf) normal normal 400 condensed>,
#  <Font 'Accanthis ADF Std No3' (AccanthisADFStdNo3-Italic.otf) italic normal 400 normal>,
#  <Font 'Liberation Sans Narrow' (LiberationSansNarrow-BoldItalic.ttf) italic normal 700 condensed>,
#  <Font 'Carlito' (Carlito-Bold.ttf) normal normal 700 normal>,
#  <Font 'GFS Artemisia' (GFSArtemisiaBold.otf) normal normal 700 normal>,
#  <Font 'Liberation Mono' (LiberationMono-Italic.ttf) italic normal 400 normal>,
#  <Font 'Ricty Diminished Discord for Powerline' (RictyDiminishedDiscord-Regular-Powerline.ttf) normal normal 400 normal>,
#  <Font 'Ricty Diminished for Powerline' (RictyDiminished-Oblique-Powerline.ttf) oblique normal 400 normal>,
#  <Font 'Ricty Diminished Discord for Powerline' (RictyDiminishedDiscord-Bold-Powerline.ttf) normal normal 700 normal>,
#  <Font 'Gillius ADF Cd' (GilliusADFCd-BoldItalic.otf) italic normal 700 normal>,
#  <Font 'Universalis ADF Cd Std' (UniversalisADFCdStd-Bold.otf) normal normal 700 normal>,
#  <Font 'Caladea' (Caladea-BoldItalic.ttf) italic normal 700 normal>,
#  <Font 'EB Garamond' (EBGaramond08-SC.ttf) normal normal 400 normal>,
#  <Font 'Roboto' (Roboto-Italic.ttf) italic normal 400 normal>,
#  <Font 'Liberation Serif' (LiberationSerif-Regular.ttf) normal normal 400 normal>,
#  <Font 'STIXVariants' (STIXVariants-Bold.otf) normal normal 700 normal>,
#  <Font 'DejaVu Sans' (DejaVuSansCondensed-Oblique.ttf) oblique normal 400 condensed>,
#  <Font 'Accanthis ADF Std No3' (AccanthisADFStdNo3-BoldItalic.otf) italic normal 700 normal>,
#  <Font 'EB Garamond' (EBGaramond08-Regular.otf) normal normal 400 normal>,
#  <Font 'GFS Artemisia' (GFSArtemisiaIt.otf) italic normal 400 normal>,
#  <Font 'STIXNonUnicode' (STIXNonUnicode-Italic.otf) italic normal 400 normal>,
#  <Font 'Linux Libertine O' (LinLibertine_RZ.otf) normal normal 600 normal>,
#  <Font 'Lobster Two' (LobsterTwo-Bold.otf) normal normal 700 normal>,
#  <Font 'Lato' (Lato-Medium.ttf) normal normal 500 normal>,
#  <Font 'Roboto' (Roboto-BlackItalic.ttf) italic normal 900 normal>,
#  <Font 'FreeMono' (FreeMonoBoldOblique.otf) oblique normal 700 normal>,
#  <Font 'STIXNonUnicode' (STIXNonUnicode-Bold.otf) normal normal 700 normal>,
#  <Font 'Ricty Diminished Discord for Powerline' (Ricty Diminished Discord Bold for Powerline.ttf) normal normal 700 normal>,
#  <Font 'GFS Solomos' (GFSSolomos.otf) normal normal 400 normal>,
#  <Font 'GFS Didot' (GFSArtemisiaBoldIt.otf) italic normal 700 normal>,
#  <Font 'Roboto' (Roboto-Light.ttf) normal normal 200 normal>,
#  <Font 'FreeSans' (FreeSansBoldOblique.otf) oblique normal 700 normal>,
#  <Font 'Lato' (Lato-Hairline.ttf) normal normal 400 normal>,
#  <Font 'Roboto' (Roboto-Thin.ttf) normal normal 400 normal>,
#  <Font 'Universalis ADF Cd Std' (UniversalisADFCdStd-BdOblique.otf) oblique normal 700 normal>,
#  <Font 'GFS Complutum' (GFSPolyglot.otf) normal normal 400 normal>,
#  <Font 'Gillius ADF' (GilliusADF-BoldItalic.otf) italic normal 700 normal>,
#  <Font 'DejaVu Sans' (DejaVuSans-ExtraLight.ttf) normal normal 200 normal>,
#  <Font 'FreeSerif' (FreeSerifBold.ttf) normal normal 700 normal>,
#  <Font 'Gillius ADF Cd' (GilliusADFCd-Bold.otf) normal normal 700 normal>,
#  <Font 'Gillius ADF' (GilliusADF-Italic.otf) italic normal 400 normal>,
#  <Font 'Gentium Basic' (GenBasI.ttf) italic normal 400 normal>,
#  <Font 'FreeSerif' (FreeSerifBold.otf) normal normal 700 normal>,
#  <Font 'Linux Biolinum O' (LinBiolinum_RI.otf) italic normal 400 normal>,
#  <Font 'Ricty Diminished' (RictyDiminished-BoldOblique.ttf) oblique normal 700 normal>,
#  <Font 'Junicode' (Junicode.ttf) normal normal 400 normal>,
#  <Font 'Ricty Diminished for Powerline' (RictyDiminished-BoldOblique-Powerline.ttf) oblique normal 700 normal>,
#  <Font 'FreeSans' (FreeSansBold.ttf) normal normal 700 normal>,
#  <Font 'EB Garamond Initials Fill2' (EBGaramond-InitialsF2.ttf) normal normal 400 normal>,
#  <Font 'Accanthis ADF Std No3' (AccanthisADFStdNo3-Regular.otf) normal normal 400 normal>,
#  <Font 'Lobster Two' (LobsterTwo-BoldItalic.otf) italic normal 700 normal>,
#  <Font 'Ricty Diminished for Powerline' (Ricty Diminished Oblique for Powerline.ttf) oblique normal 400 normal>,
#  <Font 'FreeSans' (FreeSans.otf) normal normal 400 normal>,
#  <Font 'Linux Biolinum Keyboard O' (LinBiolinum_K.otf) normal normal 400 normal>,
#  <Font 'Junicode' (Junicode-Italic.ttf) italic normal 400 normal>,
#  <Font 'Linux Libertine O' (LinLibertine_R.otf) normal normal 400 normal>,
#  <Font 'FreeMono' (FreeMono.ttf) normal normal 400 normal>,
#  <Font 'Liberation Mono' (LiberationMono-Regular.ttf) normal normal 400 normal>,
#  <Font 'STIX' (STIX-BoldItalic.otf) italic normal 700 normal>,
#  <Font 'Linux Biolinum O' (LinBiolinum_R.otf) normal normal 400 normal>,
#  <Font 'Gillius ADF No2 Cd' (GilliusADFNo2Cd-Italic.otf) italic normal 400 normal>,
#  <Font 'Lato' (Lato-SemiboldItalic.ttf) italic normal 600 normal>,
#  <Font 'STIXSizeFiveSym' (STIXSizeFiveSym-Regular.otf) normal normal 400 normal>,
#  <Font 'STIXNonUnicode' (STIXNonUnicode-BoldItalic.otf) italic normal 700 normal>,
#  <Font 'EB Garamond' (EBGaramond12-Italic.ttf) italic normal 400 normal>,
#  <Font 'GFS Neohellenic' (GFSNeohellenicBold.otf) normal normal 700 normal>,
#  <Font 'Lato' (Lato-LightItalic.ttf) italic normal 200 normal>,
#  <Font 'Ricty Diminished Discord for Powerline' (Ricty Diminished Discord Oblique for Powerline.ttf) oblique normal 400 normal>,
#  <Font 'EB Garamond' (EBGaramond12-Regular.ttf) normal normal 400 normal>,
#  <Font 'GFS Artemisia' (GFSArtemisia.otf) normal normal 400 normal>,
#  <Font 'Roboto Condensed' (RobotoCondensed-Light.ttf) normal normal 200 condensed>,
#  <Font 'Lato' (Lato-BoldItalic.ttf) italic normal 700 normal>,
#  <Font 'FreeSerif' (FreeSerifItalic.ttf) italic normal 400 normal>,
#  <Font 'FreeSans' (FreeSans.ttf) normal normal 400 normal>,
#  <Font 'EB Garamond Initials Fill1' (EBGaramond-InitialsF1.ttf) normal normal 400 normal>,
#  <Font 'Lato' (Lato-Black.ttf) normal normal 900 normal>,
#  <Font 'Gillius ADF No2' (GilliusADFNo2-BoldItalic.otf) italic normal 700 normal>,
#  <Font 'Ricty Diminished Discord' (RictyDiminishedDiscord-Regular.ttf) normal normal 400 normal>,
#  <Font 'STIXIntegralsD' (STIXIntegralsD-Regular.otf) normal normal 400 normal>,
#  <Font 'STIXIntegralsUpD' (STIXIntegralsUpD-Bold.otf) normal normal 700 normal>,
#  <Font 'Lato' (Lato-Thin.ttf) normal normal 400 normal>,
#  <Font 'EB Garamond' (EBGaramond12-Regular.otf) normal normal 400 normal>,
#  <Font 'GFS Didot' (GFSDidotBoldItalic.otf) italic normal 700 normal>,
#  <Font 'Liberation Mono' (LiberationMono-BoldItalic.ttf) italic normal 700 normal>,
#  <Font 'Gillius ADF No2' (GilliusADFNo2-Bold.otf) normal normal 700 normal>,
#  <Font 'EB Garamond Initials' (EBGaramond-Initials.otf) normal normal 400 normal>,
#  <Font 'EB Garamond' (EBGaramond12-Italic.otf) italic normal 400 normal>,
#  <Font 'Ricty Diminished for Powerline' (Ricty Diminished Regular for Powerline.ttf) normal normal 400 normal>,
#  <Font 'Caladea' (Caladea-Regular.ttf) normal normal 400 normal>,
#  <Font 'Gillius ADF No2' (GilliusADFNo2-Regular.otf) normal normal 400 normal>,
#  <Font 'Lato' (Lato-Light.ttf) normal normal 200 normal>,
#  <Font 'Universalis ADF Cd Std' (UniversalisADFCdStd-Oblique.otf) oblique normal 400 normal>,
#  <Font 'Universalis ADF Std' (UniversalisADFStd-Regular.otf) normal normal 400 normal>,
#  <Font 'Liberation Sans' (LiberationSans-Regular.ttf) normal normal 400 normal>,
#  <Font 'Accanthis ADF Std No3' (AccanthisADFStdNo3-Bold.otf) normal normal 700 normal>,
#  <Font 'STIXIntegralsUpD' (STIXIntegralsUpD-Regular.otf) normal normal 400 normal>,
#  <Font 'FreeSerif' (FreeSerifBoldItalic.otf) italic normal 700 normal>,
#  <Font 'Roboto Condensed' (RobotoCondensed-Bold.ttf) normal normal 700 condensed>,
#  <Font 'Gentium Book Basic' (GenBkBasR.ttf) normal normal 400 normal>,
#  <Font 'Liberation Sans' (LiberationSans-Bold.ttf) normal normal 700 normal>,
#  <Font 'Gentium Plus' (GentiumPlus-R.ttf) normal normal 400 normal>,
#  <Font 'Cabin' (Cabin-Bold.otf) normal normal 700 normal>,
#  <Font 'STIXGeneral' (STIXGeneral-Bold.otf) normal normal 700 normal>,
#  <Font 'FreeSans' (FreeSansOblique.ttf) oblique normal 400 normal>,
#  <Font 'STIXGeneral' (STIXGeneral-Regular.otf) normal normal 400 normal>,
#  <Font 'Ricty Diminished Discord' (RictyDiminishedDiscord-BoldOblique.ttf) oblique normal 700 normal>,
#  <Font 'Liberation Serif' (LiberationSerif-Italic.ttf) italic normal 400 normal>,
#  <Font 'Asana Math' (Asana-Math.otf) normal normal 400 normal>,
#  <Font 'STIX' (STIX-Regular.otf) normal normal 400 normal>,
#  <Font 'Cabin' (Cabin-Italic.otf) italic normal 400 normal>,
#  <Font 'EB Garamond Initials Fill1' (EBGaramond-InitialsF1.otf) normal normal 400 normal>,
#  <Font 'Gentium' (Gentium-R.ttf) normal normal 400 normal>,
#  <Font 'Gentium Plus' (GentiumPlus-I.ttf) italic normal 400 normal>,
#  <Font 'Cabin' (Cabin-MediumItalic.otf) italic normal 500 normal>,
#  <Font 'Accanthis ADF Std' (AccanthisADFStd-BoldItalic.otf) italic normal 700 normal>,
#  <Font 'Gentium Book Basic' (GenBkBasI.ttf) italic normal 400 normal>,
#  <Font 'Comfortaa' (Comfortaa-Regular.ttf) normal normal 400 normal>,
#  <Font 'Ricty Diminished' (RictyDiminished-Regular.ttf) normal normal 400 normal>,
#  <Font 'FreeSerif' (FreeSerif.otf) normal normal 400 normal>,
#  <Font 'Carlito' (Carlito-Regular.ttf) normal normal 400 normal>,
#  <Font 'Carlito' (Carlito-Italic.ttf) italic normal 400 normal>,
#  <Font 'STIXSizeOneSym' (STIXSizeOneSym-Regular.otf) normal normal 400 normal>,
#  <Font 'Lato' (Lato-HairlineItalic.ttf) italic normal 400 normal>,
#  <Font 'Liberation Sans' (LiberationSans-BoldItalic.ttf) italic normal 700 normal>,
#  <Font 'STIX Math' (STIXMath-Regular.otf) normal normal 400 normal>,
#  <Font 'STIXGeneral' (STIXGeneral-Italic.otf) italic normal 400 normal>,
#  <Font 'Roboto' (Roboto-MediumItalic.ttf) italic normal 500 normal>,
#  <Font 'Junicode' (Junicode-Bold.ttf) normal normal 700 normal>,
#  <Font 'GFS Neohellenic' (GFSNeohellenicBoldIt.otf) italic normal 700 normal>,
#  <Font 'IPAMincho' (ipam.ttf) normal normal 400 normal>,
#  <Font 'FreeSans' (FreeSansBoldOblique.ttf) oblique normal 700 normal>,
#  <Font 'Linux Libertine O' (LinLibertine_RZI.otf) italic normal 600 normal>,
#  <Font 'Cabin' (Cabin-Medium.otf) normal normal 500 normal>,
#  <Font 'Gentium Book Basic' (GenBkBasB.ttf) normal normal 400 normal>,
#  <Font 'Ricty Diminished Discord' (RictyDiminishedDiscord-Bold.ttf) normal normal 700 normal>,
#  <Font 'Gillius ADF Cd' (GilliusADFCd-Italic.otf) italic normal 400 normal>,
#  <Font 'Gillius ADF No2' (GilliusADFNo2-Italic.otf) italic normal 400 normal>,
#  <Font 'EB Garamond Initials' (EBGaramond-Initials.ttf) normal normal 400 normal>,
#  <Font 'Roboto' (Roboto-ThinItalic.ttf) italic normal 400 normal>,
#  <Font 'Liberation Sans Narrow' (LiberationSansNarrow-Bold.ttf) normal normal 700 condensed>,
#  <Font 'DejaVu Serif' (DejaVuSerifCondensed-Italic.ttf) italic normal 400 condensed>,
#  <Font 'Liberation Sans Narrow' (LiberationSansNarrow-Regular.ttf) normal normal 400 condensed>,
#  <Font 'STIXVariants' (STIXVariants-Regular.otf) normal normal 400 normal>,
#  <Font 'Gentium' (Gentium-I.ttf) italic normal 400 normal>,
#  <Font 'STIXSizeFourSym' (STIXSizeFourSym-Regular.otf) normal normal 400 normal>,
#  <Font 'STIXSizeThreeSym' (STIXSizeThreeSym-Regular.otf) normal normal 400 normal>,
#  <Font 'Caladea' (Caladea-Bold.ttf) normal normal 700 normal>,
#  <Font 'STIXIntegralsSm' (STIXIntegralsSm-Bold.otf) normal normal 700 normal>,
#  <Font 'Liberation Serif' (LiberationSerif-Bold.ttf) normal normal 700 normal>,
#  <Font 'Roboto' (Roboto-Bold.ttf) normal normal 700 normal>,
#  <Font 'STIXSizeTwoSym' (STIXSizeTwoSym-Bold.otf) normal normal 700 normal>,
#  <Font 'Cabin' (Cabin-BoldItalic.otf) italic normal 700 normal>,
#  <Font 'Lato' (Lato-MediumItalic.ttf) italic normal 500 normal>,
#  <Font 'Universalis ADF Std' (UniversalisADFStd-BoldOblique.otf) oblique normal 700 normal>,
#  <Font 'STIXGeneral' (STIXGeneral-BoldItalic.otf) italic normal 700 normal>,
#  <Font 'Roboto' (Roboto-Black.ttf) normal normal 900 normal>,
#  <Font 'Cabin' (Cabin-SemiBoldItalic.otf) italic normal 600 normal>,
#  <Font 'Roboto' (Roboto-Medium.ttf) normal normal 500 normal>,
#  <Font 'Universalis ADF Cd Std' (UniversalisADFCdStd-Regular.otf) normal normal 400 normal>,
#  <Font 'Gillius ADF Cd' (GilliusADFCd-Regular.otf) normal normal 400 normal>,
#  <Font 'EB Garamond' (EBGaramond08-Italic.otf) italic normal 400 normal>,
#  <Font 'STIXSizeThreeSym' (STIXSizeThreeSym-Bold.otf) normal normal 700 normal>,
#  <Font 'STIX' (STIX-Bold.otf) normal normal 700 normal>,
#  <Font 'STIX' (STIX-Italic.otf) italic normal 400 normal>,
#  <Font 'STIXIntegralsUpSm' (STIXIntegralsUpSm-Regular.otf) normal normal 400 normal>,
#  <Font 'Accanthis ADF Std' (AccanthisADFStd-Bold.otf) normal normal 700 normal>,
#  <Font 'FreeSans' (FreeSansBold.otf) normal normal 700 normal>,
#  <Font 'STIXIntegralsUp' (STIXIntegralsUp-Bold.otf) normal normal 700 normal>,
#  <Font 'Roboto Condensed' (RobotoCondensed-Regular.ttf) normal normal 400 condensed>,
#  <Font 'Accanthis ADF Std No2' (AccanthisADFStdNo2-Bold.otf) normal normal 700 normal>,
#  <Font 'DejaVu Serif' (DejaVuSerifCondensed.ttf) normal normal 400 condensed>,
#  <Font 'STIXSizeFourSym' (STIXSizeFourSym-Bold.otf) normal normal 700 normal>,
#  <Font 'DejaVu Sans' (DejaVuSansCondensed-Bold.ttf) normal normal 700 condensed>,
#  <Font 'GFS Didot' (GFSDidotItalic.otf) italic normal 400 normal>,
#  <Font 'GFS Didot' (GFSDidotBold.otf) normal normal 700 normal>,
#  <Font 'GentiumAlt' (GentiumAlt-R.ttf) normal normal 400 normal>,
#  <Font 'Gillius ADF' (GilliusADF-Bold.otf) normal normal 700 normal>,
#  <Font 'Lato' (Lato-Heavy.ttf) normal normal 800 normal>,
#  <Font 'Lato' (Lato-Semibold.ttf) normal normal 600 normal>,
#  <Font 'Ricty Diminished Discord for Powerline' (Ricty Diminished Discord Bold Oblique for Powerline.ttf) oblique normal 700 normal>,
#  <Font 'STIXNonUnicode' (STIXNonUnicode-Regular.otf) normal normal 400 normal>,
#  <Font 'Ricty Diminished Discord for Powerline' (RictyDiminishedDiscord-BoldOblique-Powerline.ttf) oblique normal 700 normal>,
#  <Font 'GFS Olga' (GFSOlga.otf) normal normal 400 normal>,
#  <Font 'STIXIntegralsSm' (STIXIntegralsSm-Regular.otf) normal normal 400 normal>,
#  <Font 'Ricty Diminished' (RictyDiminished-Bold.ttf) normal normal 700 normal>,
#  <Font 'Linux Libertine Mono O' (LinLibertine_M.otf) normal normal 400 normal>,
#  <Font 'Gillius ADF No2 Cd' (GilliusADFNo2Cd-BoldItalic.otf) italic normal 700 normal>,
#  <Font 'Accanthis ADF Std No2' (AccanthisADFStdNo2-BoldItalic.otf) italic normal 700 normal>,
#  <Font 'Roboto' (Roboto-BoldItalic.ttf) italic normal 700 normal>,
#  <Font 'Linux Libertine O' (LinLibertine_RBI.otf) italic normal 700 normal>,
#  <Font 'Cabin' (Cabin-SemiBold.otf) normal normal 600 normal>,
#  <Font 'Linux Libertine O' (LinLibertine_RB.otf) normal normal 700 normal>,
#  <Font 'Gillius ADF No2 Cd' (GilliusADFNo2Cd-Regular.otf) normal normal 400 normal>,
#  <Font 'Accanthis ADF Std' (AccanthisADFStd-Regular.otf) normal normal 400 normal>,
#  <Font 'Roboto Condensed' (RobotoCondensed-Italic.ttf) italic normal 400 condensed>,
#  <Font 'Comfortaa' (Comfortaa-Light.ttf) normal normal 200 normal>,
#  <Font 'Ricty Diminished Discord' (RictyDiminishedDiscord-Oblique.ttf) oblique normal 400 normal>,
#  <Font 'GFS Neohellenic' (GFSNeohellenic.otf) normal normal 400 normal>,
#  <Font 'EB Garamond Initials Fill2' (EBGaramond-InitialsF2.otf) normal normal 400 normal>,
#  <Font 'IPAGothic' (ipag.ttf) normal normal 400 normal>,
#  <Font 'IPAPMincho' (ipamp.ttf) normal normal 400 normal>,
#  <Font 'Linux Biolinum O' (LinBiolinum_RB.otf) normal normal 700 normal>,
#  <Font 'Lato' (Lato-HeavyItalic.ttf) italic normal 800 normal>,
#  <Font 'Roboto' (Roboto-Regular.ttf) normal normal 400 normal>,
#  <Font 'FreeSerif' (FreeSerif.ttf) normal normal 400 normal>,
#  <Font 'GentiumAlt' (GentiumAlt-I.ttf) italic normal 400 normal>,
#  <Font 'Lato' (Lato-ThinItalic.ttf) italic normal 400 normal>,
#  <Font 'Ricty Diminished' (RictyDiminished-Oblique.ttf) oblique normal 400 normal>]

# %%
print('ショップの総売り上げ等')
sql_str = '''
SELECT
SUM(order_item_total_price) 総売上,
SUM(order_usedpoint) 総使用ポイント,
SUM(order_getpoint) 総獲得ポイント,
SUM(order_shipping_charge) 総送料,
SUM(order_cod_fee) 総手数料,
SUM(order_tax) 総消費税
FROM wp_usces_order
WHERE order_status = 'completion,'
'''
df = sql.read_sql(sql_str, connection)
df
# Out:
# ショップの総売り上げ等
#           総売上   総使用ポイント   総獲得ポイント       総送料     総手数料      総消費税
# 0  11480342.0  803479.0  146356.0  102600.0  94500.0  933679.0

# %%
print('ショップの年間売り上げ等')
sql_str = '''
SELECT
lank 年度,
SUM(order_item_total_price) 総売上,
SUM(order_usedpoint) 総使用ポイント,
SUM(order_getpoint) 総獲得ポイント,
SUM(order_shipping_charge) 総送料,
SUM(order_cod_fee) 総手数料,
SUM(order_tax) 総消費税
FROM
(SELECT 
(CASE
WHEN `order_date` > '2014-12-31' AND `order_date` <= '2016-01-01' THEN '2015'
WHEN `order_date` > '2015-12-31' AND `order_date` <= '2017-01-01' THEN '2016'
WHEN `order_date` > '2016-12-31' AND `order_date` <= '2018-01-01' THEN '2017'
ELSE 'その他' END) AS lank,
order_item_total_price,order_usedpoint,order_getpoint,order_shipping_charge,order_cod_fee,order_tax
FROM wp_usces_order
WHERE order_status = 'completion,') AS lank
GROUP BY lank
ORDER BY lank ASC
'''
df = sql.read_sql(sql_str, connection)
df
# Out:
# ショップの年間売り上げ等
#      年度        総売上   総使用ポイント  総獲得ポイント      総送料     総手数料      総消費税
# 0  2015  2033329.0  228279.0  52561.0  19400.0  11400.0  165028.0
# 1  2016  4887223.0  249385.0  58941.0  44500.0  50100.0  398284.0
# 2  2017  4559790.0  325815.0  34854.0  38700.0  33000.0  370367.0

# %%
df.plot(title='年間売上', figsize=(20, 8), x=df.columns[0],  y=df.columns[1])

# %%
print('ショップの年別売り上げ等')
sql_str = '''
SELECT
lank 年度,
SUM(order_item_total_price) 総売上,
SUM(order_usedpoint) 総使用ポイント,
SUM(order_getpoint) 総獲得ポイント,
SUM(order_shipping_charge) 総送料,
SUM(order_cod_fee) 総手数料,
SUM(order_tax) 総消費税
FROM
(SELECT 
(CASE
WHEN `order_date` >= '2015-01-01' AND `order_date` < '2015-02-01' THEN '2015-01'
WHEN `order_date` >= '2015-02-01' AND `order_date` < '2015-03-01' THEN '2015-02'
WHEN `order_date` >= '2015-03-01' AND `order_date` < '2015-04-01' THEN '2015-03'
WHEN `order_date` >= '2015-04-01' AND `order_date` < '2015-05-01' THEN '2015-04'
WHEN `order_date` >= '2015-05-01' AND `order_date` < '2015-06-01' THEN '2015-05'
WHEN `order_date` >= '2015-06-01' AND `order_date` < '2015-07-01' THEN '2015-06'
WHEN `order_date` >= '2015-07-01' AND `order_date` < '2015-08-01' THEN '2015-07'
WHEN `order_date` >= '2015-08-01' AND `order_date` < '2015-09-01' THEN '2015-08'
WHEN `order_date` >= '2015-09-01' AND `order_date` < '2015-10-01' THEN '2015-09'
WHEN `order_date` >= '2015-10-01' AND `order_date` < '2015-11-01' THEN '2015-10'
WHEN `order_date` >= '2015-11-01' AND `order_date` < '2015-12-01' THEN '2015-11'
WHEN `order_date` >= '2015-12-01' AND `order_date` < '2016-01-01' THEN '2015-12'
WHEN `order_date` >= '2016-01-01' AND `order_date` < '2016-02-01' THEN '2016-01'
WHEN `order_date` >= '2016-02-01' AND `order_date` < '2016-03-01' THEN '2016-02'
WHEN `order_date` >= '2016-03-01' AND `order_date` < '2016-04-01' THEN '2016-03'
WHEN `order_date` >= '2016-04-01' AND `order_date` < '2016-05-01' THEN '2016-04'
WHEN `order_date` >= '2016-05-01' AND `order_date` < '2016-06-01' THEN '2016-05'
WHEN `order_date` >= '2016-06-01' AND `order_date` < '2016-07-01' THEN '2016-06'
WHEN `order_date` >= '2016-07-01' AND `order_date` < '2016-08-01' THEN '2016-07'
WHEN `order_date` >= '2016-08-01' AND `order_date` < '2016-09-01' THEN '2016-08'
WHEN `order_date` >= '2016-09-01' AND `order_date` < '2016-10-01' THEN '2016-09'
WHEN `order_date` >= '2016-10-01' AND `order_date` < '2016-11-01' THEN '2016-10'
WHEN `order_date` >= '2016-11-01' AND `order_date` < '2016-12-01' THEN '2016-11'
WHEN `order_date` >= '2016-12-01' AND `order_date` < '2017-01-01' THEN '2016-12'
WHEN `order_date` >= '2017-01-01' AND `order_date` < '2017-02-01' THEN '2017-01'
WHEN `order_date` >= '2017-02-01' AND `order_date` < '2017-03-01' THEN '2017-02'
WHEN `order_date` >= '2017-03-01' AND `order_date` < '2017-04-01' THEN '2017-03'
WHEN `order_date` >= '2017-04-01' AND `order_date` < '2017-05-01' THEN '2017-04'
WHEN `order_date` >= '2017-05-01' AND `order_date` < '2017-06-01' THEN '2017-05'
WHEN `order_date` >= '2017-06-01' AND `order_date` < '2017-07-01' THEN '2017-06'
WHEN `order_date` >= '2017-07-01' AND `order_date` < '2017-08-01' THEN '2017-07'
WHEN `order_date` >= '2017-08-01' AND `order_date` < '2017-09-01' THEN '2017-08'
WHEN `order_date` >= '2017-09-01' AND `order_date` < '2017-10-01' THEN '2017-09'
WHEN `order_date` >= '2017-10-01' AND `order_date` < '2017-11-01' THEN '2017-10'
WHEN `order_date` >= '2017-11-01' AND `order_date` < '2017-12-01' THEN '2017-11'
WHEN `order_date` >= '2017-12-01' AND `order_date` < '2018-01-01' THEN '2017-12'
ELSE 'その他' END) AS lank,
order_item_total_price,order_usedpoint,order_getpoint,order_shipping_charge,order_cod_fee,order_tax
FROM wp_usces_order
WHERE order_status = 'completion,') AS lank
GROUP BY lank
ORDER BY lank ASC
'''
df = sql.read_sql(sql_str, connection)
df
# Out:
# ショップの年別売り上げ等
#          年度       総売上  総使用ポイント  総獲得ポイント     総送料    総手数料     総消費税
# 0   2015-05   10113.0   9537.0      0.0  2500.0     0.0   1006.0
# 1   2015-06   37201.0  18861.0   1962.0  1000.0     0.0   3053.0
# 2   2015-07   52753.0  18613.0   2674.0  3500.0     0.0   4495.0
# 3   2015-08   71948.0   8804.0   2261.0  1500.0     0.0   5869.0
# 4   2015-09  303538.0  65782.0   3041.0  1500.0  2100.0  24554.0
# 5   2015-10  369157.0  19010.0   2386.0  2000.0  3300.0  29935.0
# 6   2015-11  905041.0  78508.0  30425.0  5400.0  3600.0  73089.0
# 7   2015-12  283578.0   9164.0   9812.0  2000.0  2400.0  23027.0
# 8   2016-01  622991.0  16751.0  12170.0  3400.0  6300.0  50590.0
# 9   2016-02  382773.0   5733.0   1926.0  3900.0  2700.0  31131.0
# 10  2016-03  392721.0  39839.0   1955.0  1000.0  3600.0  31770.0
# 11  2016-04  556093.0  22165.0  26135.0  3800.0  2400.0  44962.0
# 12  2016-05  388317.0  24101.0   2207.0  3000.0  4500.0  31642.0
# 13  2016-06  477273.0  27123.0   2778.0  4500.0  4200.0  38854.0
# 14  2016-07  377042.0  21050.0   1966.0  8200.0  5100.0  31200.0
# 15  2016-08  238389.0  16649.0   1496.0  5300.0  4200.0  19814.0
# 16  2016-09  353044.0  17916.0   2008.0  3000.0  3900.0  28777.0
# 17  2016-10  384999.0  21466.0   2004.0  3400.0  4800.0  31427.0
# 18  2016-11  371261.0  19021.0   2171.0  2000.0  3000.0  30078.0
# 19  2016-12  342320.0  17571.0   2125.0  3000.0  5400.0  28039.0
# 20  2017-01  546534.0   6941.0   4171.0  1500.0  2400.0  44151.0
# 21  2017-02  353663.0  23661.0   5937.0  4000.0  3900.0  28906.0
# 22  2017-03  544866.0  14214.0   2299.0  4000.0  3600.0  44054.0
# 23  2017-04  405932.0  28355.0   8631.0  3000.0  1800.0  32839.0
# 24  2017-05  382366.0  20547.0   2527.0  5400.0  2400.0  31228.0
# 25  2017-06  310962.0  29370.0   1350.0  4800.0  3600.0  25532.0
# 26  2017-07  275332.0  17720.0   1468.0  2000.0  1200.0  22264.0
# 27  2017-08  355923.0  17156.0   1693.0  1500.0  1800.0  28723.0
# 28  2017-09  464862.0  42477.0   2348.0  4500.0  3900.0  37868.0
# 29  2017-10  298798.0  44789.0   1482.0  4000.0  2700.0  24423.0
# 30  2017-11  520166.0  72704.0   2436.0  4000.0  4500.0  42262.0
# 31  2017-12  100386.0   7881.0    512.0     0.0  1200.0   8117.0

# %%
df.plot(title='月間売上', figsize=(20, 8), x=df.columns[0],  y=df.columns[1])

# %%
print('キャンセル率')
sql_str = '''
SELECT COUNT(*) 総数,
COUNT(*)/(SELECT COUNT(*) FROM wp_usces_order) * 100 キャンセル率
FROM wp_usces_order
WHERE order_status = 'cancel,'
'''
df = sql.read_sql(sql_str, connection)
df
# Out:
# キャンセル率
#     総数   キャンセル率
# 0  453  18.4221

# %%
print('月間受注数')
sql_str = '''
SELECT 
lank 年度,
COUNT(*) 受注数
FROM (SELECT 
(CASE
WHEN `order_date` >= '2015-01-01' AND `order_date` < '2015-02-01' THEN '2015-01'
WHEN `order_date` >= '2015-02-01' AND `order_date` < '2015-03-01' THEN '2015-02'
WHEN `order_date` >= '2015-03-01' AND `order_date` < '2015-04-01' THEN '2015-03'
WHEN `order_date` >= '2015-04-01' AND `order_date` < '2015-05-01' THEN '2015-04'
WHEN `order_date` >= '2015-05-01' AND `order_date` < '2015-06-01' THEN '2015-05'
WHEN `order_date` >= '2015-06-01' AND `order_date` < '2015-07-01' THEN '2015-06'
WHEN `order_date` >= '2015-07-01' AND `order_date` < '2015-08-01' THEN '2015-07'
WHEN `order_date` >= '2015-08-01' AND `order_date` < '2015-09-01' THEN '2015-08'
WHEN `order_date` >= '2015-09-01' AND `order_date` < '2015-10-01' THEN '2015-09'
WHEN `order_date` >= '2015-10-01' AND `order_date` < '2015-11-01' THEN '2015-10'
WHEN `order_date` >= '2015-11-01' AND `order_date` < '2015-12-01' THEN '2015-11'
WHEN `order_date` >= '2015-12-01' AND `order_date` < '2016-01-01' THEN '2015-12'
WHEN `order_date` >= '2016-01-01' AND `order_date` < '2016-02-01' THEN '2016-01'
WHEN `order_date` >= '2016-02-01' AND `order_date` < '2016-03-01' THEN '2016-02'
WHEN `order_date` >= '2016-03-01' AND `order_date` < '2016-04-01' THEN '2016-03'
WHEN `order_date` >= '2016-04-01' AND `order_date` < '2016-05-01' THEN '2016-04'
WHEN `order_date` >= '2016-05-01' AND `order_date` < '2016-06-01' THEN '2016-05'
WHEN `order_date` >= '2016-06-01' AND `order_date` < '2016-07-01' THEN '2016-06'
WHEN `order_date` >= '2016-07-01' AND `order_date` < '2016-08-01' THEN '2016-07'
WHEN `order_date` >= '2016-08-01' AND `order_date` < '2016-09-01' THEN '2016-08'
WHEN `order_date` >= '2016-09-01' AND `order_date` < '2016-10-01' THEN '2016-09'
WHEN `order_date` >= '2016-10-01' AND `order_date` < '2016-11-01' THEN '2016-10'
WHEN `order_date` >= '2016-11-01' AND `order_date` < '2016-12-01' THEN '2016-11'
WHEN `order_date` >= '2016-12-01' AND `order_date` < '2017-01-01' THEN '2016-12'
WHEN `order_date` >= '2017-01-01' AND `order_date` < '2017-02-01' THEN '2017-01'
WHEN `order_date` >= '2017-02-01' AND `order_date` < '2017-03-01' THEN '2017-02'
WHEN `order_date` >= '2017-03-01' AND `order_date` < '2017-04-01' THEN '2017-03'
WHEN `order_date` >= '2017-04-01' AND `order_date` < '2017-05-01' THEN '2017-04'
WHEN `order_date` >= '2017-05-01' AND `order_date` < '2017-06-01' THEN '2017-05'
WHEN `order_date` >= '2017-06-01' AND `order_date` < '2017-07-01' THEN '2017-06'
WHEN `order_date` >= '2017-07-01' AND `order_date` < '2017-08-01' THEN '2017-07'
WHEN `order_date` >= '2017-08-01' AND `order_date` < '2017-09-01' THEN '2017-08'
WHEN `order_date` >= '2017-09-01' AND `order_date` < '2017-10-01' THEN '2017-09'
WHEN `order_date` >= '2017-10-01' AND `order_date` < '2017-11-01' THEN '2017-10'
WHEN `order_date` >= '2017-11-01' AND `order_date` < '2017-12-01' THEN '2017-11'
WHEN `order_date` >= '2017-12-01' AND `order_date` < '2018-01-01' THEN '2017-12'
ELSE 'その他' END) AS lank,
order_status,
order_item_total_price
FROM wp_usces_order) AS lanks
GROUP BY lank
ORDER BY lank ASC
'''
df1 = sql.read_sql(sql_str, connection)
df1
# Out:
# 月間受注数
#          年度  受注数
# 0   2015-05    8
# 1   2015-06   24
# 2   2015-07   21
# 3   2015-08   27
# 4   2015-09   68
# 5   2015-10   74
# 6   2015-11  104
# 7   2015-12   66
# 8   2016-01   88
# 9   2016-02   65
# 10  2016-03   56
# 11  2016-04   78
# 12  2016-05   85
# 13  2016-06  103
# 14  2016-07  102
# 15  2016-08   70
# 16  2016-09   93
# 17  2016-10  116
# 18  2016-11  102
# 19  2016-12   77
# 20  2017-01   81
# 21  2017-02   87
# 22  2017-03   94
# 23  2017-04   92
# 24  2017-05   91
# 25  2017-06   64
# 26  2017-07   63
# 27  2017-08   69
# 28  2017-09  122
# 29  2017-10   98
# 30  2017-11  126
# 31  2017-12   45

# %%
print('キャンセル率')
sql_str = '''
SELECT 
COUNT(*) キャンセル数
FROM (SELECT 
(CASE
WHEN `order_date` >= '2015-01-01' AND `order_date` < '2015-02-01' THEN '2015-01'
WHEN `order_date` >= '2015-02-01' AND `order_date` < '2015-03-01' THEN '2015-02'
WHEN `order_date` >= '2015-03-01' AND `order_date` < '2015-04-01' THEN '2015-03'
WHEN `order_date` >= '2015-04-01' AND `order_date` < '2015-05-01' THEN '2015-04'
WHEN `order_date` >= '2015-05-01' AND `order_date` < '2015-06-01' THEN '2015-05'
WHEN `order_date` >= '2015-06-01' AND `order_date` < '2015-07-01' THEN '2015-06'
WHEN `order_date` >= '2015-07-01' AND `order_date` < '2015-08-01' THEN '2015-07'
WHEN `order_date` >= '2015-08-01' AND `order_date` < '2015-09-01' THEN '2015-08'
WHEN `order_date` >= '2015-09-01' AND `order_date` < '2015-10-01' THEN '2015-09'
WHEN `order_date` >= '2015-10-01' AND `order_date` < '2015-11-01' THEN '2015-10'
WHEN `order_date` >= '2015-11-01' AND `order_date` < '2015-12-01' THEN '2015-11'
WHEN `order_date` >= '2015-12-01' AND `order_date` < '2016-01-01' THEN '2015-12'
WHEN `order_date` >= '2016-01-01' AND `order_date` < '2016-02-01' THEN '2016-01'
WHEN `order_date` >= '2016-02-01' AND `order_date` < '2016-03-01' THEN '2016-02'
WHEN `order_date` >= '2016-03-01' AND `order_date` < '2016-04-01' THEN '2016-03'
WHEN `order_date` >= '2016-04-01' AND `order_date` < '2016-05-01' THEN '2016-04'
WHEN `order_date` >= '2016-05-01' AND `order_date` < '2016-06-01' THEN '2016-05'
WHEN `order_date` >= '2016-06-01' AND `order_date` < '2016-07-01' THEN '2016-06'
WHEN `order_date` >= '2016-07-01' AND `order_date` < '2016-08-01' THEN '2016-07'
WHEN `order_date` >= '2016-08-01' AND `order_date` < '2016-09-01' THEN '2016-08'
WHEN `order_date` >= '2016-09-01' AND `order_date` < '2016-10-01' THEN '2016-09'
WHEN `order_date` >= '2016-10-01' AND `order_date` < '2016-11-01' THEN '2016-10'
WHEN `order_date` >= '2016-11-01' AND `order_date` < '2016-12-01' THEN '2016-11'
WHEN `order_date` >= '2016-12-01' AND `order_date` < '2017-01-01' THEN '2016-12'
WHEN `order_date` >= '2017-01-01' AND `order_date` < '2017-02-01' THEN '2017-01'
WHEN `order_date` >= '2017-02-01' AND `order_date` < '2017-03-01' THEN '2017-02'
WHEN `order_date` >= '2017-03-01' AND `order_date` < '2017-04-01' THEN '2017-03'
WHEN `order_date` >= '2017-04-01' AND `order_date` < '2017-05-01' THEN '2017-04'
WHEN `order_date` >= '2017-05-01' AND `order_date` < '2017-06-01' THEN '2017-05'
WHEN `order_date` >= '2017-06-01' AND `order_date` < '2017-07-01' THEN '2017-06'
WHEN `order_date` >= '2017-07-01' AND `order_date` < '2017-08-01' THEN '2017-07'
WHEN `order_date` >= '2017-08-01' AND `order_date` < '2017-09-01' THEN '2017-08'
WHEN `order_date` >= '2017-09-01' AND `order_date` < '2017-10-01' THEN '2017-09'
WHEN `order_date` >= '2017-10-01' AND `order_date` < '2017-11-01' THEN '2017-10'
WHEN `order_date` >= '2017-11-01' AND `order_date` < '2017-12-01' THEN '2017-11'
WHEN `order_date` >= '2017-12-01' AND `order_date` < '2018-01-01' THEN '2017-12'
ELSE 'その他' END) AS lank,
order_status
FROM wp_usces_order) AS lanks
WHERE order_status = 'cancel,'
GROUP BY lank
ORDER BY lank ASC
'''
df2 = sql.read_sql(sql_str, connection)
df2
# Out:
# キャンセル率
#     キャンセル数
# 0        3
# 1        3
# 2        1
# 3        1
# 4       12
# 5       15
# 6       16
# 7       16
# 8       11
# 9       11
# 10       8
# 11      14
# 12      22
# 13      13
# 14      22
# 15      16
# 16      20
# 17      25
# 18      24
# 19      12
# 20      18
# 21      25
# 22      16
# 23      24
# 24      21
# 25       6
# 26       7
# 27       8
# 28      19
# 29      15
# 30      21
# 31       8

# %%
print('月間キャンセル')
df = pd.concat([df1, df2], axis=1)
df
df.plot(kind='line', figsize=(20, 8), x=df.columns[0],  y=[df.columns[1],df.columns[2]])
# Out:
# 月間キャンセル

# %%
print('購入方法の割合')
sql_str = '''
SELECT order_payment_name 購入方法, 
COUNT(*) 総数,
COUNT(*)/(SELECT COUNT(*) FROM wp_usces_order) * 100 パーセント
FROM wp_usces_order
GROUP BY order_payment_name
'''
df = sql.read_sql(sql_str, connection)
df
# Out:
# 購入方法の割合
#                  購入方法    総数    パーセント
# 0              #none#     1   0.0407
# 1               クレジット  1037  42.1716
# 2      クレジット・全額ポイント決済     6   0.2440
# 3           ペイジー・コンビニ     2   0.0813
# 4  ペイジー・コンビニ・全額ポイント決済    56   2.2773
# 5                代金引換  1030  41.8869
# 6            全額ポイント決済   327  13.2981

# %%
df.plot.bar(x='購入方法', y='パーセント')

# %%
print('受注の都道府県の割合')
sql_str = '''
SELECT order_pref 都道府県, 
COUNT(*) 総数,
COUNT(*)/(SELECT COUNT(*) FROM wp_usces_order) * 100 パーセント
FROM wp_usces_order
GROUP BY order_pref
ORDER BY 総数 DESC
'''
df = sql.read_sql(sql_str, connection)
df
# Out:
# 受注の都道府県の割合
#       都道府県   総数    パーセント
# 0      大阪府  466  18.9508
# 1      兵庫県  321  13.0541
# 2      東京都  140   5.6934
# 3      愛知県  136   5.5307
# 4     神奈川県  128   5.2054
# 5     和歌山県   93   3.7820
# 6      京都府   80   3.2534
# 7      千葉県   74   3.0094
# 8      静岡県   74   3.0094
# 9      福岡県   72   2.9280
# 10     三重県   54   2.1960
# 11     愛媛県   47   1.9113
# 12     広島県   44   1.7893
# 13     埼玉県   42   1.7080
# 14     岐阜県   40   1.6267
# 15     長野県   38   1.5453
# 16     福島県   37   1.5047
# 17    鹿児島県   29   1.1793
# 18     山形県   29   1.1793
# 19     新潟県   28   1.1387
# 20     滋賀県   28   1.1387
# 21     岡山県   25   1.0167
# 22     山口県   24   0.9760
# 23     徳島県   24   0.9760
# 24     香川県   24   0.9760
# 25     宮崎県   24   0.9760
# 26     福井県   23   0.9353
# 27     長崎県   23   0.9353
# 28     青森県   22   0.8947
# 29     熊本県   22   0.8947
# 30     茨城県   22   0.8947
# 31     石川県   22   0.8947
# 32     島根県   22   0.8947
# 33     高知県   21   0.8540
# 34     宮城県   19   0.7727
# 35     奈良県   18   0.7320
# 36     栃木県   15   0.6100
# 37     大分県   15   0.6100
# 38     秋田県   15   0.6100
# 39     富山県   14   0.5693
# 40     北海道   14   0.5693
# 41     鳥取県   12   0.4880
# 42     岩手県   10   0.4067
# 43     沖縄県    8   0.3253
# 44     佐賀県    7   0.2847
# 45     山梨県    7   0.2847
# 46     群馬県    6   0.2440
# 47  --選択--    1   0.0407

# %%
df.plot(title="都道府県別販売数", kind="bar", figsize=(20, 8), x=df.columns[0],  y=df.columns[1])

# %%
# 受注の価格帯
sql_str = '''
SELECT lank 価格帯,
COUNT(*) 総数,
COUNT(*)/(SELECT COUNT(*) FROM wp_usces_order) * 100 パーセント,
SUM(order_item_total_price)　総売上,
SUM(order_item_total_price)/(SELECT SUM(order_item_total_price) FROM wp_usces_order) * 100 売上パーセント
FROM
(SELECT
(CASE
WHEN `order_item_total_price` > 0 AND `order_item_total_price` <= 1000 THEN '0~1000'
WHEN `order_item_total_price` > 1000 AND `order_item_total_price` <= 2000 THEN '01000~2000'
WHEN `order_item_total_price` > 2000 AND `order_item_total_price` <= 3000 THEN '02000~3000'
WHEN `order_item_total_price` > 3000 AND `order_item_total_price` <= 4000 THEN '03000~4000'
WHEN `order_item_total_price` > 4000 AND `order_item_total_price` <= 5000 THEN '04000~5000'
WHEN `order_item_total_price` > 5000 AND `order_item_total_price` <= 6000 THEN '05000~6000'
WHEN `order_item_total_price` > 6000 AND `order_item_total_price` <= 7000 THEN '06000~7000'
WHEN `order_item_total_price` > 7000 AND `order_item_total_price` <= 8000 THEN '07000~8000'
WHEN `order_item_total_price` > 8000 AND `order_item_total_price` <= 9000 THEN '08000~9000'
WHEN `order_item_total_price` > 9000 AND `order_item_total_price` <= 10000 THEN '09000~10000'
WHEN `order_item_total_price` > 10000 AND `order_item_total_price` <= 11000 THEN '10000~11000'
WHEN `order_item_total_price` > 11000 AND `order_item_total_price` <= 12000 THEN '11000~12000'
WHEN `order_item_total_price` > 12000 AND `order_item_total_price` <= 13000 THEN '12000~13000'
ELSE 'その他' END) AS lank,
order_item_total_price
FROM `wp_usces_order`) as lank
GROUP BY lank
ORDER BY lank ASC
'''
df = sql.read_sql(sql_str, connection)
df
# Out:
#             価格帯   総数    パーセント       　総売上    売上パーセント
# 0    01000~2000  200   8.1334   308547.0   1.790700
# 1    02000~3000  163   6.6287   415110.0   2.409155
# 2    03000~4000  723  29.4022  2471598.0  14.344301
# 3    04000~5000  294  11.9561  1314712.0   7.630134
# 4    05000~6000  244   9.9227  1339692.0   7.775110
# 5    06000~7000  127   5.1647   830322.0   4.818902
# 6    07000~8000  123   5.0020   919259.0   5.335062
# 7    08000~9000   74   3.0094   627444.0   3.641468
# 8   09000~10000   54   2.1960   515353.0   2.990931
# 9        0~1000   73   2.9687    53278.0   0.309207
# 10  10000~11000   38   1.5453   401042.0   2.327509
# 11  11000~12000   36   1.4640   414324.0   2.404593
# 12  12000~13000   61   2.4807   763082.0   4.428664
# 13          その他  249  10.1261  6856759.0  39.794262

# %%
df.plot(title="受注の価格帯", kind="bar", figsize=(20, 8), x=df.columns[0],  y=df.columns[1])

# %%
# 受注ごとの商品販売商品数
sql_str = '''
SELECT count 販売商品数,
COUNT(count) この販売商品数だったものの総数,
COUNT(count)/(SELECT COUNT(*) FROM wp_usces_order) * 100 as パーセント
FROM
(SELECT count(oc.order_id) count, SUM(oc.price) sum FROM wp_usces_order wo
INNER JOIN wp_usces_ordercart oc
ON wo.ID = oc.order_id
GROUP BY oc.order_id) order_count
GROUP BY count
'''
df = sql.read_sql(sql_str, connection)
df
# Out:
#     販売商品数  この販売商品数だったものの総数    パーセント
# 0       1             1364  55.4697
# 1       2              537  21.8381
# 2       3              272  11.0614
# 3       4              128   5.2054
# 4       5               52   2.1147
# 5       6               36   1.4640
# 6       7               18   0.7320
# 7       8               14   0.5693
# 8       9                7   0.2847
# 9      10                8   0.3253
# 10     11                4   0.1627
# 11     12                5   0.2033
# 12     13                1   0.0407
# 13     14                5   0.2033
# 14     15                1   0.0407
# 15     16                1   0.0407
# 16     17                1   0.0407
# 17     18                1   0.0407
# 18     19                1   0.0407
# 19     25                1   0.0407

# %%
df.plot(title="受注ごとの商品販売商品数", kind="bar", figsize=(20, 8), x=df.columns[0],  y=df.columns[1])

# %%
# 受注商品の価格帯
sql_str = '''
SELECT lank 価格帯,
COUNT(*) 総数, 
COUNT(*)/(SELECT COUNT(*) FROM wp_usces_ordercart) * 100 パーセント,
SUM(price)　総売上,
SUM(price)/(SELECT SUM(price) FROM wp_usces_ordercart) * 100 売上パーセント
FROM
(SELECT
(CASE
WHEN `price` > 0 AND `price` <= 1000 THEN '0~1000'
WHEN `price` > 1000 AND `price` <= 2000 THEN '01000=2000'
WHEN `price` > 2000 AND `price` <= 3000 THEN '02000~3000'
WHEN `price` > 3000 AND `price` <= 4000 THEN '03000~4000'
WHEN `price` > 4000 AND `price` <= 5000 THEN '04000~5000'
WHEN `price` > 5000 AND `price` <= 6000 THEN '05000~6000'
WHEN `price` > 6000 AND `price` <= 7000 THEN '06000~7000'
WHEN `price` > 7000 AND `price` <= 8000 THEN '07000~8000'
WHEN `price` > 8000 AND `price` <= 9000 THEN '08000~9000'
WHEN `price` > 9000 AND `price` <= 10000 THEN '09000~10000'
WHEN `price` > 10000 AND `price` <= 11000 THEN '10000~11000'
WHEN `price` > 11000 AND `price` <= 12000 THEN '11000~12000'
WHEN `price` > 12000 AND `price` <= 13000 THEN '12000~13000'
ELSE 'その他' END) AS lank,
price
FROM `wp_usces_ordercart`) as lank
GROUP BY lank
ORDER BY lank ASC
'''
df = sql.read_sql(sql_str, connection)
df
# Out:
#             価格帯    総数    パーセント       　総売上    売上パーセント
# 0    01000=2000  1767  35.9146  2605054.0  18.461790
# 1    02000~3000   563  11.4431  1409854.0   9.991512
# 2    03000~4000   426   8.6585  1476787.0  10.465860
# 3    04000~5000   147   2.9878   658844.0   4.669170
# 4    05000~6000    77   1.5650   426857.0   3.025098
# 5    06000~7000    38   0.7724   248769.0   1.763004
# 6    07000~8000    46   0.9350   343891.0   2.437125
# 7    08000~9000    21   0.4268   177490.0   1.257856
# 8   09000~10000    22   0.4472   210323.0   1.490541
# 9        0~1000  1567  31.8496  1073250.0   7.606029
# 10  10000~11000    13   0.2642   138164.0   0.979156
# 11  11000~12000    15   0.3049   174110.0   1.233902
# 12  12000~13000    51   1.0366   639062.0   4.528977
# 13          その他   167   3.3943  4528062.0  32.089979

# %%
df.plot(title="受注商品の価格帯", kind="bar", figsize=(20, 8), x=df.columns[0],  y=df.columns[1])

# %%
print('商品ジャンル 売り上げ個数ランク')
sql_str = '''
SELECT wt.name ジャンル名,
COUNT(wt.name) 総数
FROM `wp_usces_ordercart`oc
INNER JOIN wp_posts po
ON oc.post_id = po.ID
INNER JOIN wp_term_relationships wtr
ON po.ID = wtr.object_id
INNER JOIN wp_term_taxonomy wtt
ON wtr.term_taxonomy_id = wtt.term_taxonomy_id
INNER JOIN wp_terms wt
ON wtt.term_id = wt.term_id
WHERE wtt.parent = 5
GROUP BY wt.name
ORDER BY 総数 DESC
'''
df = sql.read_sql(sql_str, connection)
df
# Out:
# 商品ジャンル 売り上げ個数ランク
#             ジャンル名   総数
# 0         エサ釣り仕掛け  550
# 1             ルアー  502
# 2              ジグ  485
# 3             ライン  433
# 4              エギ  427
# 5             ツール  350
# 6    エサ釣り用バラ針・オモリ  235
# 7             ロッド  211
# 8    ルアー用フック・シンカー  161
# 9        スッテ・イカヅノ  152
# 10            ワーム  137
# 11     スナップ・サルカン類   97
# 12   カブラ・テンヤ・インチク   91
# 13       タックルボックス   88
# 14         ウキ・シモリ   86
# 15          集魚パーツ   84
# 16            リール   73
# 17             タモ   71
# 18   ジグヘッド・その他フック   65
# 19     ハサミ・プライヤー類   65
# 20        ウェア・バッグ   63
# 21            ライト   59
# 22  クーラーボックス・保冷用品   18
# 23         ロッドケース    9
# 24          ヤエン用品    7

# %%
# 釣り方 売り上げ個数ランク
sql_str = '''
SELECT wt.name as 釣り方,
COUNT(wt.name) 総数
FROM `wp_usces_ordercart`oc
INNER JOIN wp_posts po
ON oc.post_id = po.ID
INNER JOIN wp_term_relationships wtr
ON po.ID = wtr.object_id
INNER JOIN wp_term_taxonomy wtt
ON wtr.term_taxonomy_id = wtt.term_taxonomy_id
INNER JOIN wp_terms wt
ON wtt.term_id = wt.term_id
WHERE wtt.parent IN (221,231,246,256)
GROUP BY wt.name
ORDER BY 総数 DESC
'''
df = sql.read_sql(sql_str, connection)
df
# Out:
#                          釣り方    総数
# 0                       シーバス  1079
# 1                 アジング・メバリング  1055
# 2                     ライトゲーム  1009
# 3                       ジギング   999
# 4                       エギング   982
# 5                    ショアジギング   851
# 6                   ロックフィッシュ   816
# 7                    ボートシーバス   805
# 8                    ボートエギング   761
# 9                 チヌ・クロダイゲーム   707
# 10                  ボートメバリング   700
# 11                ショアキャスティング   699
# 12                 フラットフィッシュ   689
# 13                    サーベリング   626
# 14               ボートロックフィッシュ   602
# 15                     イカメタル   597
# 16                     フカセ釣り   592
# 17                      ワインド   580
# 18                      投げ釣り   570
# 19              キャスティング（トップ）   566
# 20                  オクトパッシング   564
# 21                      カゴ釣り   564
# 22                      ウキ釣り   562
# 23                    船マダイ釣り   545
# 24    ヤリイカ・スルメイカ・ケンサキ（マイカ）釣り   544
# 25                    エビ撒き釣り   543
# 26                     キッシング   542
# 27                ボートチヌ・クロダイ   526
# 28                     サビキ釣り   525
# 29                   タチウオ餌釣り   522
# 30  船ワラサ（メジロ）・ブリ・ヒラマサ・カンパチ釣り   519
# 31                  探り釣り・穴釣り   514
# 32                船マアジ・マサバ釣り   510
# 33                     ちょい投げ   507
# 34               船イナダ（ハマチ）釣り   507
# 35                     イカ餌釣り   506
# 36                      底物釣り   502
# 37                  タイラバ・テンヤ   498
# 38                      海上釣堀   498
# 39                    船メバル釣り   495
# 40                     筏チヌ釣り   493
# 41                    船ヒラメ釣り   482
# 42                    ぶっこみ釣り   481
# 43                 のませ・喰わせ釣り   479
# 44                   船タチウオ釣り   476
# 45                    船イサキ釣り   463
# 46                   船カワハギ釣り   458
# 47                       胴突き   457
# 48                       ヤエン   455
# 49                     タコ餌釣り   454
# 50                    ティップラン   452
# 51                  紀州・ダンゴ釣り   451
# 52                     船キス釣り   449
# 53                       脈釣り   449
# 54               船カサゴ（ガシラ）釣り   444
# 55                    船カレイ釣り   443
# 56                 落とし込み・前打ち   414
# 57                     船底物釣り   362
# 58                     船上物釣り   340
# 59                     船タコ釣り   315
# 60                船マグロ・ヨコワ釣り   300

# %%
sql_str = '''
SELECT
wt.name,
wtt.count
FROM wp_terms wt
INNER JOIN wp_term_taxonomy wtt
ON wtt.term_id = wt.term_id
WHERE wtt.parent IN (272)
'''
df = sql.read_sql(sql_str, connection)
df
# Out:
#                     name  count
# 0                    ダイワ   1125
# 1                    シマノ    495
# 2                   ハリミツ    328
# 3                  シャウト！    376
# 4                   明邦化学    231
# 5                 ベイトブレス     35
# 6                   ささめ針    832
# 7                   冨士灯器    194
# 8                   宇崎日新   1148
# 9                   ハヤブサ     14
# 10    デュエル(DUEL・YO-ZURI)   1039
# 11                 サンライン     63
# 12                  第一精工    306
# 13               YGKよつあみ    257
# 14                  ユニチカ    304
# 15                 ZEXUS     65
# 16                    墨族    506
# 17               MAGBITE    112
# 18              ヤマガブランクス    185
# 19            TICT（ティクト）    184
# 20          スタジオオーシャンマーク    115
# 21              メジャークラフト    781
# 22                  コアマン     86
# 23                ジップベイツ     96
# 24               ジャンプライズ     40
# 25                  タナハシ    112
# 26                  バスデイ     71
# 27              ラッキークラフト     80
# 28               ランブルベイト     33
# 29                ガンクラフト    231
# 30                 かわせみ針     11
# 31                   マル呑      4
# 32               ジャングルジム     53
# 33          アングラーズリパブリック     73
# 34               エバーグリーン   1812
# 35              ゴールデンミーン    318
# 36           プロックス(PROX)    204
# 37                   脇漁具     18
# 38        JACKALL（ジャッカル）    804
# 39                  加藤精工      2
# 40                  下田漁具      4
# 41  Fish Arrow（フィッシュアロー）    265
# 42               ＦタックルＧＯ      3
# 43             オーシャンルーラー     24
# 44    JFF(ジェイフラッグフィッシング)      2
# 45                  UOYA     82
# 46            クレイジーオーシャン     92
# 47                    剣屋     91
# 48                 TIEUP     22
# 49                 Zefar     13
# 50                    東レ      0
# 51                   クレハ    132
# 52                   カンジ    143
# 53                  SLPW      1
# 54              ima（アイマ）    414
# 55                   DUO      0
# 56                  ヤマリア    647
# 57                  JAZZ     12
# 58            XESTA（ゼスタ）    187
# 59    Abu Garcia(アブガルシア)    326
# 60                   その他      8
# 61             OGK（大阪漁具）     63
# 62            アングラーズデザイン     85
# 63               タックルハウス     31
# 64           昌栄（SIYOUEI）    281
# 65           ルミカ（LUMICA）     90
# 66           Rapala(ラパラ)     44
# 67           STORM(ストーム)     14
# 68             TRIGGER-X      6
# 69                  がまかつ   1031
# 70           NORTH CRAFT     29
# 71               ラインシステム      1
# 72        Megabass（メガバス）    210
# 73                 名光通信社      7
# 74     Go-Phish（ゴーフィッシュ）     14
# 75             アピア（APIA）    230
# 76                  モーリス    292
# 77           FLASH UNION     40
# 78                  カツイチ   1047
# 79                 DECOY    231
# 80                パズデザイン     85
# 81             ZEAL(ジール)     58
# 82        BREADEN(ブリーデン)      0
# 83                 ベルモント   1457
# 84              NADA（ナダ）     89
# 85           RYUGI(リューギ)     61
# 86         Magical Baits      1

# %%
# メーカー 売り上げランク
sql_str = '''
SELECT wt.name メーカー,
COUNT(wt.name) 総数,
FORMAT(SUM( CASE when wo.order_status LIKE '%cancel%' then 1 ELSE 0 END  ), 0) キャンセル総数,
FORMAT(SUM(oc.price),0) 売上
FROM `wp_usces_ordercart`oc
INNER JOIN wp_usces_order wo
ON wo.ID = oc.order_id
INNER JOIN wp_posts po
ON oc.post_id = po.ID
INNER JOIN wp_term_relationships wtr
ON po.ID = wtr.object_id
INNER JOIN wp_term_taxonomy wtt
ON wtr.term_taxonomy_id = wtt.term_taxonomy_id
INNER JOIN wp_terms wt
ON wtt.term_id = wt.term_id
WHERE wtt.parent IN (272)
GROUP BY wt.name
ORDER BY 総数 DESC
'''
df = sql.read_sql(sql_str, connection)
df
# Out:
#                     メーカー   総数 キャンセル総数       売上
# 0                   ささめ針  435      34  633,182
# 1                   ハリミツ  273      31  548,172
# 2                エバーグリーン  237       5  527,450
# 3                   がまかつ  222      29  686,899
# 4                  シャウト！  212       4  313,065
# 5                YGKよつあみ  211      22  458,692
# 6             クレイジーオーシャン  205      16  638,394
# 7            プロックス(PROX)  205      31  616,749
# 8     デュエル(DUEL・YO-ZURI)  170      34  181,278
# 9                     墨族  154      21  115,256
# 10                  第一精工  146      14  357,403
# 11               タックルハウス  113       5  156,520
# 12            XESTA（ゼスタ）  113       4  939,170
# 13                    剣屋  101       9  724,305
# 14                   脇漁具   90       3   60,127
# 15           STORM(ストーム)   81       9   56,917
# 16           ルミカ（LUMICA）   80       1   59,300
# 17                 サンライン   68      19  110,456
# 18            TICT（ティクト）   59       7  214,659
# 19                   カンジ   59       4  158,221
# 20     Go-Phish（ゴーフィッシュ）   56       4  176,040
# 21              ima（アイマ）   56       3   82,323
# 22                   クレハ   56       3   88,172
# 23                 DECOY   47       8   82,850
# 24                  冨士灯器   46       6   42,098
# 25                  ヤマリア   46       5  172,365
# 26                  UOYA   44       3   32,043
# 27           Rapala(ラパラ)   44       6   53,401
# 28               ランブルベイト   41      15   63,750
# 29           昌栄（SIYOUEI）   40       5  167,290
# 30  Fish Arrow（フィッシュアロー）   36       3   59,523
# 31                  明邦化学   33       4   96,479
# 32              ラッキークラフト   32       6   40,832
# 33               MAGBITE   32       1   60,786
# 34                  ユニチカ   32       3   44,837
# 35                   ダイワ   30       8  338,574
# 36               ジャンプライズ   29       5   56,442
# 37             アピア（APIA）   29      12  105,442
# 38                ジップベイツ   28       9   41,264
# 39                 ベルモント   26       6   30,547
# 40                ガンクラフト   23       0   21,198
# 41              ゴールデンミーン   22       1   65,555
# 42                  宇崎日新   22       5  705,079
# 43                   シマノ   22      18  593,384
# 44              メジャークラフト   21       2  239,556
# 45        JACKALL（ジャッカル）   20       1   31,589
# 46                  カツイチ   18       4   28,000
# 47                  JAZZ   17       1   15,948
# 48               ジャングルジム   16       2   23,879
# 49              NADA（ナダ）   14       3   83,353
# 50                  モーリス   14       0   26,480
# 51                  タナハシ   12       7   58,568
# 52              ヤマガブランクス   12       5  368,600
# 53    Abu Garcia(アブガルシア)   11       6  174,926
# 54             OGK（大阪漁具）   10       0   53,978
# 55                ベイトブレス    9       0   25,560
# 56            アングラーズデザイン    9       3   51,576
# 57          スタジオオーシャンマーク    8       4   76,200
# 58                 ZEXUS    7       0   41,888
# 59                 かわせみ針    6       0    4,668
# 60        Megabass（メガバス）    6       2    7,354
# 61           RYUGI(リューギ)    5       2   20,900
# 62                パズデザイン    3       0    4,815
# 63           FLASH UNION    3       0    4,701
# 64    JFF(ジェイフラッグフィッシング)    3       0    8,799
# 65                   その他    2       0    5,780
# 66          アングラーズリパブリック    2       0   29,200
# 67           NORTH CRAFT    2       1    3,010
# 68                  バスデイ    2       0    2,904
# 69                 Zefar    1       0    7,861

# %%
# メーカー 売り上げランク
sql_str = '''
SELECT
count_tb.メーカー,
count_tb.登録数,
(CASE WHEN sell_tb.販売総数 is NULL THEN 0 ELSE sell_tb.販売総数 END) 販売総数,
sell_tb.キャンセル総数,
sell_tb.売上
FROM (
SELECT
wt.name メーカー,
wtt.count 登録数
FROM wp_terms wt
LEFT OUTER JOIN wp_term_taxonomy wtt
ON wtt.term_id = wt.term_id
WHERE wtt.parent IN (272)
) count_tb
LEFT OUTER JOIN (
SELECT wt.name メーカー,
COUNT(wt.name) 販売総数,
SUM( CASE when wo.order_status LIKE '%cancel%' then 1 ELSE 0 END  ) キャンセル総数,
SUM(oc.price) 売上
FROM `wp_usces_ordercart`oc
INNER JOIN wp_usces_order wo
ON wo.ID = oc.order_id
INNER JOIN wp_posts po
ON oc.post_id = po.ID
INNER JOIN wp_term_relationships wtr
ON po.ID = wtr.object_id
INNER JOIN wp_term_taxonomy wtt
ON wtr.term_taxonomy_id = wtt.term_taxonomy_id
INNER JOIN wp_terms wt
ON wtt.term_id = wt.term_id
WHERE wtt.parent IN (272)
GROUP BY wt.name
ORDER BY 販売総数 DESC
) sell_tb
ON sell_tb.メーカー = count_tb.メーカー
'''
df = sql.read_sql(sql_str, connection)
df
# Out:
#                     メーカー   登録数  販売総数  キャンセル総数        売上
# 0                    ダイワ  1125    30      8.0  338574.0
# 1                    シマノ   495    22     18.0  593384.0
# 2                   ハリミツ   328   273     31.0  548172.0
# 3                  シャウト！   376   212      4.0  313065.0
# 4                   明邦化学   231    33      4.0   96479.0
# 5                 ベイトブレス    35     9      0.0   25560.0
# 6                   ささめ針   832   435     34.0  633182.0
# 7                   冨士灯器   194    46      6.0   42098.0
# 8                   宇崎日新  1148    22      5.0  705079.0
# 9                   ハヤブサ    14     0      NaN       NaN
# 10    デュエル(DUEL・YO-ZURI)  1039   170     34.0  181278.0
# 11                 サンライン    63    68     19.0  110456.0
# 12                  第一精工   306   146     14.0  357403.0
# 13               YGKよつあみ   257   211     22.0  458692.0
# 14                  ユニチカ   304    32      3.0   44837.0
# 15                 ZEXUS    65     7      0.0   41888.0
# 16                    墨族   506   154     21.0  115256.0
# 17               MAGBITE   112    32      1.0   60786.0
# 18              ヤマガブランクス   185    12      5.0  368600.0
# 19            TICT（ティクト）   184    59      7.0  214659.0
# 20          スタジオオーシャンマーク   115     8      4.0   76200.0
# 21              メジャークラフト   781    21      2.0  239556.0
# 22                  コアマン    86     0      NaN       NaN
# 23                ジップベイツ    96    28      9.0   41264.0
# 24               ジャンプライズ    40    29      5.0   56442.0
# 25                  タナハシ   112    12      7.0   58568.0
# 26                  バスデイ    71     2      0.0    2904.0
# 27              ラッキークラフト    80    32      6.0   40832.0
# 28               ランブルベイト    33    41     15.0   63750.0
# 29                ガンクラフト   231    23      0.0   21198.0
# 30                 かわせみ針    11     6      0.0    4668.0
# 31                   マル呑     4     0      NaN       NaN
# 32               ジャングルジム    53    16      2.0   23879.0
# 33          アングラーズリパブリック    73     2      0.0   29200.0
# 34               エバーグリーン  1812   237      5.0  527450.0
# 35              ゴールデンミーン   318    22      1.0   65555.0
# 36           プロックス(PROX)   204   205     31.0  616749.0
# 37                   脇漁具    18    90      3.0   60127.0
# 38        JACKALL（ジャッカル）   804    20      1.0   31589.0
# 39                  加藤精工     2     0      NaN       NaN
# 40                  下田漁具     4     0      NaN       NaN
# 41  Fish Arrow（フィッシュアロー）   265    36      3.0   59523.0
# 42               ＦタックルＧＯ     3     0      NaN       NaN
# 43             オーシャンルーラー    24     0      NaN       NaN
# 44    JFF(ジェイフラッグフィッシング)     2     3      0.0    8799.0
# 45                  UOYA    82    44      3.0   32043.0
# 46            クレイジーオーシャン    92   205     16.0  638394.0
# 47                    剣屋    91   101      9.0  724305.0
# 48                 TIEUP    22     0      NaN       NaN
# 49                 Zefar    13     1      0.0    7861.0
# 50                    東レ     0     0      NaN       NaN
# 51                   クレハ   132    56      3.0   88172.0
# 52                   カンジ   143    59      4.0  158221.0
# 53                  SLPW     1     0      NaN       NaN
# 54              ima（アイマ）   414    56      3.0   82323.0
# 55                   DUO     0     0      NaN       NaN
# 56                  ヤマリア   647    46      5.0  172365.0
# 57                  JAZZ    12    17      1.0   15948.0
# 58            XESTA（ゼスタ）   187   113      4.0  939170.0
# 59    Abu Garcia(アブガルシア)   326    11      6.0  174926.0
# 60                   その他     8     2      0.0    5780.0
# 61             OGK（大阪漁具）    63    10      0.0   53978.0
# 62            アングラーズデザイン    85     9      3.0   51576.0
# 63               タックルハウス    31   113      5.0  156520.0
# 64           昌栄（SIYOUEI）   281    40      5.0  167290.0
# 65           ルミカ（LUMICA）    90    80      1.0   59300.0
# 66           Rapala(ラパラ)    44    44      6.0   53401.0
# 67           STORM(ストーム)    14    81      9.0   56917.0
# 68             TRIGGER-X     6     0      NaN       NaN
# 69                  がまかつ  1031   222     29.0  686899.0
# 70           NORTH CRAFT    29     2      1.0    3010.0
# 71               ラインシステム     1     0      NaN       NaN
# 72        Megabass（メガバス）   210     6      2.0    7354.0
# 73                 名光通信社     7     0      NaN       NaN
# 74     Go-Phish（ゴーフィッシュ）    14    56      4.0  176040.0
# 75             アピア（APIA）   230    29     12.0  105442.0
# 76                  モーリス   292    14      0.0   26480.0
# 77           FLASH UNION    40     3      0.0    4701.0
# 78                  カツイチ  1047    18      4.0   28000.0
# 79                 DECOY   231    47      8.0   82850.0
# 80                パズデザイン    85     3      0.0    4815.0
# 81             ZEAL(ジール)    58     0      NaN       NaN
# 82        BREADEN(ブリーデン)     0     0      NaN       NaN
# 83                 ベルモント  1457    26      6.0   30547.0
# 84              NADA（ナダ）    89    14      3.0   83353.0
# 85           RYUGI(リューギ)    61     5      2.0   20900.0
# 86         Magical Baits     1     0      NaN       NaN

# %%
df.plot.bar(title='メーカーの登録数と販売総数の比較', x='メーカー', y=[ '登録数', '販売総数'], figsize=(30, 8), alpha=0.6)

# %%
# 問屋 売り上げランク
sql_str = '''
SELECT wt.name 問屋,
COUNT(wt.name) 総数
FROM `wp_usces_ordercart`oc
INNER JOIN wp_posts po
ON oc.post_id = po.ID
INNER JOIN wp_term_relationships wtr
ON po.ID = wtr.object_id
INNER JOIN wp_term_taxonomy wtt
ON wtr.term_taxonomy_id = wtt.term_taxonomy_id
INNER JOIN wp_terms wt
ON wtt.term_id = wt.term_id
WHERE wtt.parent IN (281)
GROUP BY wt.name
ORDER BY 総数 DESC
'''
df = sql.read_sql(sql_str, connection)
df
# Out:
#          問屋    総数
# 0     松浦テグス  1621
# 1        魚矢  1335
# 2      中央漁具   721
# 3      大阪漁具   261
# 4  株式会社デュエル   170
# 5      谷山商事   122
# 6   株式会社ルミカ    80
# 7      メジャー    21

# %%
# 商品個別 売り上げランク
sql_str = '''
SELECT oc.item_name 商品名,
COUNT(post_id) 販売回数,
COUNT(post_id)/(SELECT COUNT(*) FROM wp_usces_ordercart) * 100 パーセント,
SUM(quantity) 販売総数
FROM `wp_usces_ordercart` oc
GROUP BY oc.item_name
ORDER BY 販売回数 DESC
'''
df = sql.read_sql(sql_str, connection)
df
# Out:
#                                             商品名  販売回数   パーセント  販売総数
# 0                                    鉛トンボニューパール    66  1.3415  73.0
# 1                          ジャベリンジェット　小型回遊魚対応モデル    64  1.3008  91.0
# 2                                   スライドアンサーヘッド    47  0.9553  61.0
# 3                    SHORESストリーマー（ショアーズ　ストリーマー）    38  0.7724  42.0
# 4              ブラックダイニーマ（グランドスーパーＰＥブラック）　100ｍ連結    30  0.6098  99.0
# 5                                       ガンガンジグ２    30  0.6098  34.0
# 6                                         クレイドル    26  0.5285  27.0
# 7                                   ハオリ・スリム&ロング    24  0.4878  26.0
# 8                                サーフェスウィング　１４７Ｆ    24  0.4878  32.0
# 9                                     極テンヤ船用　ラメ    22  0.4472  80.0
# 10                                          ランス    21  0.4268  21.0
# 11                                       コルセア６５    20  0.4065  31.0
# 12                                    ソーラン ブレード    19  0.3862  58.0
# 13                                       ジャベリン　    19  0.3862  19.0
# 14        クリックス　プロスペック　#08　ディープパープル／レッド　（3本セット）    18  0.3659  34.0
# 15                       ジグパラ [ Jigpara ]　５個セット    18  0.3659  40.0
# 16                         イセエビスペシャル　5本鈎（5枚セット）    18  0.3659  45.0
# 17                                       ＢＰＰトンボ    17  0.3455  24.0
# 18                                    オーシャンシンカー    17  0.3455  22.0
# 19                                  オーシャンナイトJr.    16  0.3252  16.0
# 20                        イセエビ替針　お徳用１０組入（5枚セット）    16  0.3252  32.0
# 21                                       ダンガンジグ    16  0.3252  29.0
# 22                                ザブラモンスーンブレーカー    16  0.3252  19.0
# 23                                   百海サーフ 2.5号    15  0.3049  20.0
# 24                   よつあみ　ウルトラダイニーマ ブラック　100m連結    14  0.2846  64.0
# 25                                      カプリスキッド    14  0.2846  14.0
# 26             タケダ クラフト（TAKEDA CRAFT）アジのエサ 2インチ    14  0.2846  17.0
# 27                                    ジャベリンジェット    14  0.2846  14.0
# 28           タケダクラフト（TAKEDA CRAFT） アジのエサ 1.5インチ    13  0.2642  13.0
# 29                           ハドルミノーハード 65/80 SW    13  0.2642  13.0
# 30                                         ライテン    13  0.2642  15.0
# 31               カーボンソリッド　IZANAGI　紫電 掛　SP562SMS    13  0.2642  13.0
# 32                                    レブロス（’15）    13  0.2642  13.0
# 33                           船太刀胴突テンヤ　仕掛（5枚セット）    13  0.2642  13.0
# 34                            五目ジグ　3g・5g・8g・12g    13  0.2642  13.0
# 35                             五目ジグ 20g・30g・40g    12  0.2439  12.0
# 36                       真鯛フカセ３本　１０ｍ　１５ｍ（5枚セット）    12  0.2439  12.0
# 37                              タコエギジャック(3本セット)    12  0.2439  14.0
# 38                              カラーチヌ胴打　(5枚セット)    12  0.2439  15.0
# 39                               アオリーＱ　エース　ディープ    12  0.2439  20.0
# 40                         ガリス　キャストマンアブソーバー　５０ｍ    12  0.2439  12.0
# 41    ブラックスター スターワーム（STAR WORM） スティックスター（5枚セット）    11  0.2236  13.0
# 42              クリックス　プロスペック　#21　薩摩オレンジ　（3本セット）    11  0.2236  13.0
# 43                              オーシャンフラッシュ　１６０ｇ    11  0.2236  11.0
# 44                               磯ハンターライン　50ｍ連結    11  0.2236  16.0
# 45                              ボラ両掛(茶)（10袋セット）    11  0.2236  15.0
# 46       チェルム　アンバーコードSG　S-PETポリエステル　150ｍハンガーパック    11  0.2236  14.0
# 47                              オーシャンフラッシュ　１３０ｇ    11  0.2236  13.0
# 48                                  海毛虫 (4袋セット)    11  0.2236  11.0
# 49                          カーボンソリッド　IZANAGI　甘蕉    11  0.2236  11.0
# ...                                         ...   ...     ...   ...
# 1947                           トレブル12(銀)（5袋セット）     1  0.0203   1.0
# 1948                          ソルパラ　EGING series     1  0.0203   2.0
# 1949                           アオリーＱ　ＲＳ　24 MK59     1  0.0203   1.0
# 1950                                  サイドステップSF     1  0.0203   5.0
# 1951                           ライトリグリーダー（5枚セット）     1  0.0203   1.0
# 1952                                   リバード 90S     1  0.0203   1.0
# 1953                                 ＥＶＡロッドラック　     1  0.0203   1.0
# 1954                                     磯 遠投EV     1  0.0203   1.0
# 1955                             アオリーＱ　エース　シャロー     1  0.0203   6.0
# 1956                            墨族　VE-22RHBアカアオ     1  0.0203   2.0
# 1957                     定番カワハギ胴突仕掛　3本鈎（10袋セット）     1  0.0203   1.0
# 1958                              激釣アマダイ(5枚セット)     1  0.0203   2.0
# 1959                     海上釣堀 喰い渋りスペシャル　(5枚セット)     1  0.0203   1.0
# 1960                          アシスト59 ライト（5袋セット）     1  0.0203   1.0
# 1961                             墨族　ＶＥ−２２ＩＳ　イサキ     1  0.0203   1.0
# 1962                VE-50SZ-13　零王 シャロータイプ　アメジスト     1  0.0203   1.0
# 1963                           Galahad ジギングシリーズ     1  0.0203   1.0
# 1964                   ランディングフレームinoプラス（ロックタイプ）     1  0.0203   1.0
# 1965                               ケプラートＧＸ　１０ｍ物     1  0.0203   1.0
# 1966                        餌木邪　＃ＳＨ−０２　将軍ピンクイワシ     1  0.0203   2.0
# 1967                      ＥＺ−Ｑ　キャスト　ラトル　05 KVRP     1  0.0203   1.0
# 1968               SALTYSTAGE KR-X Ajing Custom     1  0.0203   1.0
# 1969                        コンビネーションケース GM-2070     1  0.0203   1.0
# 1970                         チヌ１．６ｍ付（黒）　(5枚セット)     1  0.0203   1.0
# 1971                                   イカラーク９０　     1  0.0203   2.0
# 1972                            墨族　ＶＥ−２２ＲＨＹ　アカキ     1  0.0203   1.0
# 1973                       道具屋　競技キスハリス止　(5枚セット)     1  0.0203   4.0
# 1974                      クロステージ　KURODAI series     1  0.0203   1.0
# 1975                     アオリイカ　Ｖ型　エサ針タイプ（5枚セット）     1  0.0203   1.0
# 1976                                    ジャスティーン     1  0.0203   2.0
# 1977                         根魚ボッコボコ仕掛３本（5枚セット）     1  0.0203   1.0
# 1978                  糸付 ワンタッチスナップチヌ1M付（10袋セット）     1  0.0203   2.0
# 1979               イカリーダー　大山・大王崎スペシャル１０本（5枚セット）     1  0.0203   1.0
# 1980                     E-109　堤防五目さぐり先生（5枚セット）     1  0.0203   1.0
# 1981                     シーバスアシスト 岸壁ジギング（5袋セット）     1  0.0203   1.0
# 1982                         アオリーＱ　エース　RAJ　3.5号     1  0.0203   5.0
# 1983   エルア　ショアガン　Conpressed F.C. Spining Models     1  0.0203   1.0
# 1984                  喰い渋りタチウオ替鈎 つらぬき仕様（10袋セット）     1  0.0203   1.0
# 1985                             VS-E6551（ホワイト）     1  0.0203   1.0
# 1986                         メダイフカセ　２本３ｍ（5枚セット）     1  0.0203   2.0
# 1987                              荒喰い五目　(5枚セット)     1  0.0203   1.0
# 1988                     エギエスツーベータ　ピンク イエロー レッド     1  0.0203   1.0
# 1989                            改良カレイイレグ(5枚セット)     1  0.0203   5.0
# 1990                         豆イカ仕掛 チビ太君（10袋セット）     1  0.0203   1.0
# 1991                                    メガスピンＺ３     1  0.0203   1.0
# 1992                               リバティクラブ　シーバス     1  0.0203   1.0
# 1993                                   モアザン ガルバ     1  0.0203   2.0
# 1994                         インナーボックスＳ　マルチストッカー     1  0.0203   1.0
# 1995                                ハンディ ボックス L     1  0.0203   2.0
# 1996                       LEDライト　ＺＸ−270BK　ブラック     1  0.0203   1.0
#
# [1997 rows x 4 columns]
